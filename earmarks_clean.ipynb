# %% [markdown]
# # earmarks vs. disaster risk
#
# Brazilian lawmakers direct billions in earmarked funds to specific places. Part of this money is related to climate mitigation and adaptation. this project aims to find if this distribution follows evidence regarding projected risk or past climate events for flood and landslide. I rebuilt this notebook to reorganize it after several mistakes were made in an earlier version

# %%
import os
import pandas as pd

# %% [markdown]
# ## earmarks table
# Downloaded from Portal da Transparência

# %%
emendas = pd.read_csv('data/dados_brutos/EmendasParlamentares.csv', sep=';', encoding='latin1')
emendas.head()
# Out:
# /var/folders/n_/3j3vmvq51gz0dc6g0xjknkm80000gn/T/ipykernel_27345/735340104.py:1: DtypeWarning: Columns (0: Código da Emenda, 1: Código do Autor da Emenda, 2: Número da emenda) have mixed types. Specify dtype option on import or set low_memory=False.
#   emendas = pd.read_csv('data/dados_brutos/EmendasParlamentares.csv', sep=';', encoding='latin1')
#   Código da Emenda  Ano da Emenda  \
# 0   Sem informação           2014
# 1   Sem informação           2014
# 2   Sem informação           2014
# 3   Sem informação           2014
# 4   Sem informação           2014
#
#                                       Tipo de Emenda  \
# 0  Emenda Individual - Transferências com Finalid...
# 1  Emenda Individual - Transferências com Finalid...
# 2  Emenda Individual - Transferências com Finalid...
# 3  Emenda Individual - Transferências com Finalid...
# 4  Emenda Individual - Transferências com Finalid...
#
#   Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 0                       S/I          Sem informação              S/I
# 1                       S/I          Sem informação              S/I
# 2                       S/I          Sem informação              S/I
# 3                       S/I          Sem informação              S/I
# 4                       S/I          Sem informação              S/I
#
#   Localidade de aplicação do recurso Código Município IBGE        Município  \
# 0                         FEIJÓ - AC               1200302            FEIJÓ
# 1                  MINAS GERAIS (UF)        Sem informação   Sem informação
# 2                      COMODORO - MT               5103304         COMODORO
# 3               PINDAMONHANGABA - SP               3538006  PINDAMONHANGABA
# 4                       SOBRADO - PB               2515971          SOBRADO
#
#    Código UF IBGE  ... Código Ação  \
# 0         1200000  ...        7652
# 1         3100000  ...        14UF
# 2         5100000  ...        20ZV
# 3         3500000  ...        8581
# 4         2500000  ...        8581
#
#                                            Nome Ação  \
# 0  IMPLANTACAO DE MELHORIAS SANITARIAS DOMICILIAR...
# 1  CONSTRUCAO, REFORMA, EQUIPAGEM E AMPLIACAO DE ...
# 2                      FOMENTO AO SETOR AGROPECUARIO
# 3  ESTRUTURACAO DA REDE DE SERVICOS DE ATENCAO PR...
# 4  ESTRUTURACAO DA REDE DE SERVICOS DE ATENCAO PR...
#
#   Código Plano Orçamentário  \
# 0                      0000
# 1                      0000
# 2                      0000
# 3                      0000
# 4                      0000
#
#                              Nome Plano Orçamentário Valor Empenhado  \
# 0  IMPLANTACAO DE MELHORIAS SANITARIAS DOMICILIAR...       250000,00
# 1  CONSTRUCAO, REFORMA, EQUIPAGEM E AMPLIACAO DE ...      3143341,40
# 2  FOMENTO AO SETOR AGROPECUARIO - DESPESAS DIVERSAS       243750,00
# 3  ESTRUTURACAO DA REDE DE SERVICOS DE ATENCAO BA...       159644,37
# 4  ESTRUTURACAO DA REDE DE SERVICOS DE ATENCAO BA...       379000,00
#
#   Valor Liquidado Valor Pago Valor Restos A Pagar Inscritos  \
# 0            0,00       0,00                           0,00
# 1            0,00       0,00                      830201,40
# 2            0,00       0,00                           0,00
# 3            0,00       0,00                           0,00
# 4            0,00       0,00                           0,00
#
#   Valor Restos A Pagar Cancelados Valor Restos A Pagar Pagos
# 0                       250000,00                       0,00
# 1                       830201,40                 2313140,00
# 2                            0,00                  243750,00
# 3                            0,00                  159644,37
# 4                            0,00                  379000,00
#
# [5 rows x 28 columns]

# %%
#2023-2026, fixing dots, commas
emendas = emendas[emendas['Ano da Emenda'].isin([2023, 2024, 2025, 2026])]
emendas["Ano da Emenda"].unique()
# Out:
# array([2023, 2024, 2025, 2026])

# %%
emendas['Valor Empenhado'] = emendas['Valor Empenhado'].str.replace('.','').str.replace(',','.').astype(float)
emendas.head()
# Out:
#       Código da Emenda  Ano da Emenda  \
# 69583     202338950001           2023
# 69584     202338950002           2023
# 69585     202338950003           2023
# 69586     202338950004           2023
# 69587     202338950005           2023
#
#                                           Tipo de Emenda  \
# 69583  Emenda Individual - Transferências com Finalid...
# 69584  Emenda Individual - Transferências com Finalid...
# 69585  Emenda Individual - Transferências com Finalid...
# 69586  Emenda Individual - Transferências com Finalid...
# 69587  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 69583                      3895          ABILIO SANTANA                1
# 69584                      3895          ABILIO SANTANA                2
# 69585                      3895          ABILIO SANTANA                3
# 69586                      3895          ABILIO SANTANA                4
# 69587                      3895          ABILIO SANTANA                5
#
#       Localidade de aplicação do recurso Código Município IBGE  \
# 69583              CORAÇÃO DE MARIA - BA               2908903
# 69584                        CORIBE - BA               2909109
# 69585                           MÚLTIPLO        Sem informação
# 69586                        ITATIM - BA               2916856
# 69587               SANTA TERESINHA - BA               2928505
#
#               Município  Código UF IBGE  ... Código Ação  \
# 69583  CORAÇÃO DE MARIA         2900000  ...        2E89
# 69584            CORIBE         2900000  ...        2E89
# 69585          Múltiplo         2900000  ...        2E89
# 69586            ITATIM         2900000  ...        2E90
# 69587   SANTA TERESINHA         2900000  ...        2E89
#
#                                                Nome Ação  \
# 69583  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69584  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69585  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69586  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69587  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
#
#       Código Plano Orçamentário  \
# 69583                      0000
# 69584                      0000
# 69585                      0000
# 69586                      0000
# 69587                      0000
#
#                                  Nome Plano Orçamentário Valor Empenhado  \
# 69583  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       1500000.0
# 69584  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       2000000.0
# 69585  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       8218164.0
# 69586  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...        600000.0
# 69587  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       1500000.0
#
#       Valor Liquidado  Valor Pago Valor Restos A Pagar Inscritos  \
# 69583      1500000,00  1500000,00                           0,00
# 69584      2000000,00  2000000,00                           0,00
# 69585      8218164,00  8218164,00                           0,00
# 69586       600000,00   600000,00                           0,00
# 69587      1500000,00  1500000,00                           0,00
#
#       Valor Restos A Pagar Cancelados Valor Restos A Pagar Pagos
# 69583                            0,00                       0,00
# 69584                            0,00                       0,00
# 69585                            0,00                       0,00
# 69586                            0,00                       0,00
# 69587                            0,00                       0,00
#
# [5 rows x 28 columns]

# %% [markdown]
# ## environmental filter
#
# Inesc published a report on climate financing that lists 97 budget action codes for environmental work

# %%
from natural_pdf import PDF

pdf = PDF('data/dados_brutos/inesc.pdf')
len(pdf.pages)
# Out:
# 58

# %%
table = pdf.pages[25].extract_table()
for row in table:
    print(row)
# Out:
# ['ento\nRegional', 'Desastre\ns', 'Defesa Civil\npara a\nEstruturação\ndo Órgão\nCoordenador\ndo Sistema\nFederal de\nProteção e\nDefesa Civil', '', '']
# ['53000 -\nMinistério da\nIntegração e\ndo\nDesenvolvim\nento\nRegional', '2318 -\nGestão\nde\nRiscos e\nde\nDesastre\ns', '22BO - Ações\nde Proteção e\nDefesa Civil', '800.00\n0.000', '100']
# ['53000 -\nMinistério da\nIntegração e\ndo\nDesenvolvim\nento\nRegional', '2318 -\nGestão\nde\nRiscos e\nde\nDesastre\ns', '8172 -\nCoordenação e\nFortalecimento\ndo Sistema\nNacional de\nProteção e\nDefesa Civil\n(SINPDEC)', '10.600.\n000', '5.391.800']
# ['53000 -\nMinistério da\nIntegração e\ndo\nDesenvolvim', '2318 -\nGestão\nde\nRiscos e\nde', '8348 - Apoio às\nAções\nEmergenciais\nde Prevenção e\nMitigação para', '600.00\n0', '600.100']

# %%
table = pdf.pages[25].extract_table(method="text")
for row in table:
    print(row)
# Out:
# [None, None, None, None, None]
# [None, None, None, None, None]
# ['ento', 'Desastre', 'Defesa Civil', None, None]
# ['Regional', 's', 'para a', None, None]
# [None, None, 'Estruturação', None, None]
# [None, None, 'do Órgão', None, None]
# [None, None, 'Coordenador', None, None]
# [None, None, 'do Sistema', None, None]
# [None, None, 'Federal de', None, None]
# [None, None, 'Proteção e', None, None]
# [None, None, 'Defesa Civil', None, None]
# [None, None, None, None, None]
# ['53000 -', '2318 -', '22BO - Ações', '800.00', '100']
# ['Ministério da', 'Gestão', 'de Proteção e', '0.000', None]
# ['Integração e', 'de', 'Defesa Civil', None, None]
# ['do', 'Riscos e', None, None, None]
# ['Desenvolvim', 'de', None, None, None]
# ['ento', 'Desastre', None, None, None]
# ['Regional', 's', None, None, None]
# [None, None, None, None, None]
# ['53000 -', '2318 -', '8172 -', '10.600.', '5.391.800']
# ['Ministério da', 'Gestão', 'Coordenação e', '000', None]
# ['Integração e', 'de', 'Fortalecimento', None, None]
# ['do', 'Riscos e', 'do Sistema', None, None]
# ['Desenvolvim', 'de', 'Nacional de', None, None]
# ['ento', 'Desastre', 'Proteção e', None, None]
# ['Regional', 's', 'Defesa Civil', None, None]
# [None, None, '(SINPDEC)', None, None]
# [None, None, None, None, None]
# ['53000 -', '2318 -', '8348 - Apoio às', '600.00', '600.100']
# ['Ministério da', 'Gestão', 'Ações', '0', None]
# ['Integração e', 'de', 'Emergenciais', None, None]
# ['do', 'Riscos e', 'de Prevenção e', None, None]
# ['Desenvolvim', 'de', 'Mitigação para', None, None]

# %%
#classified codes (dont put me in prision!!!!) 
codigos = ["20G4", "20VA", "20VY", "216W", "21E4", "00UD", "20VP", "21F1", "21F2", "10TT", "20WH", "21A9", "6925", "21HR", "000K", "00T5", "00TK", "20GB", "21HC", "21HP", "21HQ", "22BO", "8172", "8348", "8865", "00LX", "00T6", "00T7", "00T8", "00T9", "00TA", "00TB", "00TG", "00UN", "00VA", "00WP", "11AA", "12EP", "14VI", "152D", "15DX", "15XT", "15XV", "15XW", "15ZK", "162K", "166K", "169E", "1N64", "20N4", "20VR", "20VS", "20WI", "214T", "219H", "21DD", "21DE", "21DF", "21DG", "21HX", "2378", "4926", "5308", "5900", "7G88", "7M12", "7X91", "7XZ4", "00UO", "219R", "4909", "00SY", "8872", "8874", "00SW", "00T2", "00TH", "00TJ", "00VC", "00VD", "168N", "20W2", "20WM", "20WN", "214M", "214N", "214O", "214P", "218R", "219K", "21F3", "21F4", "21F5", "21HJ", "21HK", "21I5", "2E87"]
len(codigos)
# Out:
# 97

# %%
#How many earmarks are environmental?
ambientais = emendas[emendas['Código Ação'].isin(codigos)]
ambientais.head()
# Out:
#       Código da Emenda  Ano da Emenda  \
# 69799     202327760019           2023
# 69899     202330420002           2023
# 69942     202310740007           2023
# 69959     202320830015           2023
# 70021     202339150004           2023
#
#                                           Tipo de Emenda  \
# 69799  Emenda Individual - Transferências com Finalid...
# 69899  Emenda Individual - Transferências com Finalid...
# 69942  Emenda Individual - Transferências com Finalid...
# 69959  Emenda Individual - Transferências com Finalid...
# 70021  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 69799                      2776        ALESSANDRO MOLON               19
# 69899                      3042          ALTINEU CORTES                2
# 69942                      1074          ANDRE DE PAULA                7
# 69959                      2083        ANDRE FIGUEIREDO               15
# 70021                      3915          AROLDO MARTINS                4
#
#       Localidade de aplicação do recurso Código Município IBGE  \
# 69799                RIO DE JANEIRO (UF)        Sem informação
# 69899                   SÃO GONÇALO - RJ               3304904
# 69942                    ITAPISSUMA - PE               2607752
# 69959                        RUSSAS - CE               2311801
# 70021                        PARANÁ (UF)        Sem informação
#
#             Município  Código UF IBGE  ... Código Ação  \
# 69799  Sem informação         3300000  ...        20WM
# 69899     SÃO GONÇALO         3300000  ...        00SY
# 69942      ITAPISSUMA         2600000  ...        00T5
# 69959          RUSSAS         2300000  ...        2E87
# 70021  Sem informação         4100000  ...        2E87
#
#                                                Nome Ação  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...
# 69959  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# 70021  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
#
#       Código Plano Orçamentário  \
# 69799                      0000
# 69899                      0000
# 69942                      0000
# 69959                      0000
# 70021                      0000
#
#                                  Nome Plano Orçamentário Valor Empenhado  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...       488667.88
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...     12219069.00
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...       500000.00
# 69959  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       250000.00
# 70021  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       162920.00
#
#       Valor Liquidado Valor Pago Valor Restos A Pagar Inscritos  \
# 69799            0,00       0,00                       12805,02
# 69899       518333,00  518333,00                    11700736,00
# 69942            0,00       0,00                      143976,05
# 69959            0,00       0,00                       70400,00
# 70021            0,00       0,00                           0,00
#
#       Valor Restos A Pagar Cancelados Valor Restos A Pagar Pagos
# 69799                            0,00                  475862,86
# 69899                            0,00                       0,00
# 69942                            0,00                  356023,95
# 69959                            0,00                  179600,00
# 70021                            0,00                  162920,00
#
# [5 rows x 28 columns]

# %%
#cities
ambientais['Município']
# Out:
# 69799    Sem informação
# 69899       SÃO GONÇALO
# 69942        ITAPISSUMA
# 69959            RUSSAS
# 70021    Sem informação
#               ...
# 93683    Sem informação
# 93693    RIO DE JANEIRO
# 93805    CAMPINA GRANDE
# 93873    Sem informação
# 93894            CUIABÁ
# Name: Município, Length: 269, dtype: str

# %% [markdown]
# ## Risk scores from AdaptaBrasil
# landslide and floods as indicators

# %%
import requests
url ="https://sistema.adaptabrasil.mcti.gov.br/api/hierarquia/adaptabrasil"
response = requests.get(url).json()
len(response)
# Out:
# 558

# %%
response[0]
# Out:
# {'id': 0,
#  'name': 'Base conceitual conforme definições\xa0do\xa0IPCC',
#  'title': 'Risco Climático',
#  'shortname': 'Risco Climático',
#  'simple_description': 'Base conceitual conforme definições\xa0do\xa0IPCC',
#  'complete_description': '<html><p><img src="https://s3.us-east-1.amazonaws.com/cache-sistema.adaptabrasil.dev.apps.rnp.br/imagens/flor-de-risco3.png" alt="Riscos"><br>\nNo AdaptaBrasil&comma; o risco clim&aacute;tico combina tr&ecirc;s fatores: Amea&ccedil;a clim&aacute;tica&comma; Exposi&ccedil;&atilde;o e Vulnerabilidade. A Amea&ccedil;a clim&aacute;tica &eacute; a possibilidade de acontecerem eventos extremos&comma; como chuvas fortes&comma; enchentes ou secas&comma; capazes de causar  perdas econ&ocirc;micas&comma; impactos ambientais ou at&eacute; colocar vidas em risco. Esses efeitos podem variar de acordo com o setor analisado. A Exposi&ccedil;&atilde;o refere-se &agrave; exist&ecirc;ncia de elementos aos quais a amea&ccedil;a clim&aacute;tica pode causar danos&comma; sejam eles pessoas&comma; esp&eacute;cies&comma; ecossistemas ou infraestruturas. A Vulnerabilidade indica a predisposi&ccedil;&atilde;o de uma &aacute;rea ser afetada pelos impactos das mudan&ccedil;as do clima&comma; sendo composta pela Sensibilidade (o quanto a &aacute;rea pode ser imediatamente afetada pela amea&ccedil;a clim&aacute;tica)&comma; e pela Capacidade adaptativa (a habilidade de se preparar&comma; reagir e se adaptar &agrave; amea&ccedil;a clim&aacute;tica&comma; seja prevenindo os riscos ou reduzindo os impactos depois que eles ocorrem). O &Iacute;ndice de Risco Clim&aacute;tico &eacute; calculado para cada setor e munic&iacute;pio do Brasil. Para mais informa&ccedil;&otilde;es&comma;&nbsp;clique <a href="https://www.youtube.com/watch?v=-9rgniOaViM" target="_blank">aqui</a>.</html>',
#  'equation': None,
#  'level': 0,
#  'pessimist': None,
#  'indicator_id_master': 'None',
#  'years': [],
#  'years_description': None,
#  'scenarios': None,
#  'imageurl': None,
#  'sep_id': None,
#  'sep_description': None,
#  'disturbance': None,
#  'geometrytype': 'MultiPolygon',
#  'measurement_unit': None,
#  'climate_hazard': None,
#  'legend': None,
#  'menu_structure': None,
#  'color': '#FFFFFF'}

# %%
dados = response

# %%
import pandas as pd

riskadapta = pd.DataFrame(dados)

riskadapta.head()
# Out:
#       id                                         name  \
# 0      0  Base conceitual conforme definições do IPCC
# 1      1                            Recursos hídricos
# 2   5000                          Segurança alimentar
# 3  10000                         Segurança energética
# 4  40000                     Infraestrutura portuária
#
#                                     title                 shortname  \
# 0                         Risco Climático           Risco Climático
# 1         Impactos para recursos hídricos         Recursos hídricos
# 2       Impactos para segurança alimentar       Segurança alimentar
# 3      Impactos para segurança energética      Segurança energética
# 4  Impactos para infraestrutura portuária  Infraestrutura portuária
#
#                                   simple_description  \
# 0        Base conceitual conforme definições do IPCC
# 1  Consequências esperadas e resultantes das muda...
# 2  Consequências esperadas e resultantes das muda...
# 3  Consequências esperadas e resultantes das muda...
# 4  Consequências esperadas e resultantes das muda...
#
#                                 complete_description equation  level  \
# 0  <html><p><img src="https://s3.us-east-1.amazon...     None      0
# 1  São os efeitos sobre vidas, meios de subsistên...     None      1
# 2  Os impactos sobre vidas, meios de subsistência...     None      1
# 3  São os efeitos sobre vidas, meios de subsistên...     None      1
# 4  São os efeitos sobre vidas, meios de subsistên...     None      1
#
#    pessimist indicator_id_master  ...  \
# 0        NaN                None  ...
# 1        NaN                   0  ...
# 2        1.0                   0  ...
# 3        1.0                   0  ...
# 4        1.0                   0  ...
#
#                                             imageurl sep_id  \
# 0                                                NaN    NaN
# 1  https://s3.sa-east-1.amazonaws.com/cache-siste...    1.0
# 2  https://s3.sa-east-1.amazonaws.com/cache-siste...    2.0
# 3  https://s3.sa-east-1.amazonaws.com/cache-siste...    3.0
# 4  https://s3.sa-east-1.amazonaws.com/cache-siste...    4.0
#
#                                      sep_description disturbance  \
# 0                                                NaN        None
# 1  <div className="raiz-text"><span className="ra...        None
# 2  <div className="raiz-text"><span className="ra...        None
# 3  <div className="raiz-text"><span className="ra...        None
# 4  <div className="raiz-text"><span className="ra...        None
#
#    geometrytype measurement_unit climate_hazard  \
# 0  MultiPolygon             None           None
# 1  MultiPolygon             None           None
# 2  MultiPolygon             None           None
# 3  MultiPolygon             None           None
# 4    MultiPoint             None           None
#
#                                               legend  \
# 0                                               None
# 1                                               None
# 2  {'items': [{'order': 1, 'label': 'Muito baixo'...
# 3  {'items': [{'order': 1, 'label': 'Muito baixo'...
# 4  {'items': [{'order': 1, 'label': 'Muito baixo'...
#
#                                       menu_structure    color
# 0                                               None  #FFFFFF
# 1  {'defaultclippingresolution': {'id': 1, 'cid':...      NaN
# 2  {'defaultclippingresolution': {'id': 1, 'cid':...      NaN
# 3  {'defaultclippingresolution': {'id': 1, 'cid':...      NaN
# 4  {'defaultclippingresolution': {'id': 4, 'cid':...      NaN
#
# [5 rows x 23 columns]

# %%
for item in response:
    if 'eslizamento' in item['name'] or 'nundaç' in item['name']:
        print(item['name'])
# Out:
# Deslizamento de terra
# Inundações, enxurradas e alagamentos
# Alagamento e inundação
# Deslizamento
# Deslizamento
# Vulnerabilidade à inundação
# Suscetibilidade a deslizamentos
# Suscetibilidade a deslizamentos

# %%
for item in response:
    if 'eslizamento' in item['name'] or 'nundaç' in item['name']:
        print(item['id'], item['name'])
# Out:
# 60001 Deslizamento de terra
# 60041 Inundações, enxurradas e alagamentos
# 70001 Alagamento e inundação
# 70014 Deslizamento
# 80001 Deslizamento
# 70005 Vulnerabilidade à inundação
# 70018 Suscetibilidade a deslizamentos
# 80005 Suscetibilidade a deslizamentos

# %%
for item in response:
    if item['id'] in [60001, 60041]:
        print(item['id'], item['years'])
# Out:
# 60001 [2015, 2030, 2050]
# 60041 [2015, 2030, 2050]

# %% [markdown]
# ## Scores
#
# API AdaptaBrasil
# '/mapa-dados/BR/municipio/{indicator}/{year}/{scenario}/adaptabrasil'

# %%
url = "https://sistema.adaptabrasil.mcti.gov.br/api/mapa-dados/BR/municipio/60001/2030/null/adaptabrasil"
teste = requests.get(url).json()
len(teste)
# Out:
# 0

# %%
url = "https://sistema.adaptabrasil.mcti.gov.br/api/mapa-dados/BR/municipio/60001/2015/null/adaptabrasil"
deslizamento =pd.DataFrame(requests.get(url).json())

deslizamento.shape
# Out:
# (5570, 10)

# %%
url = "https://sistema.adaptabrasil.mcti.gov.br/api/mapa-dados/BR/municipio/60041/2015/null/adaptabrasil"
inundacao = pd.DataFrame(requests.get(url).json())
inundacao.shape
# Out:
# (5570, 10)

# %%
deslizamento.head()
# Out:
#      id geocod_ibge                    name  indicator_id  year scenario_id  \
# 0  2644     5200050      Abadia de Goiás/GO         60001  2015        None
# 1   754     3100104  Abadia dos Dourados/MG         60001  2015        None
# 2  2645     5200100            Abadiânia/GO         60001  2015        None
# 3   755     3100203               Abaeté/MG         60001  2015        None
# 4  2938     1500107           Abaetetuba/PA         60001  2015        None
#
#    pessimist  value valuecolor   rangelabel
# 0          1   0.12    #02C650  Muito baixo
# 1          1   0.54    #FFCD00        Médio
# 2          1   0.49    #FFCD00        Médio
# 3          1   0.40    #FFCD00        Médio
# 4          1   0.48    #FFCD00        Médio

# %%
inundacao.head()
# Out:
#      id geocod_ibge                    name  indicator_id  year scenario_id  \
# 0  2644     5200050      Abadia de Goiás/GO         60041  2015        None
# 1   754     3100104  Abadia dos Dourados/MG         60041  2015        None
# 2  2645     5200100            Abadiânia/GO         60041  2015        None
# 3   755     3100203               Abaeté/MG         60041  2015        None
# 4  2938     1500107           Abaetetuba/PA         60041  2015        None
#
#    pessimist  value valuecolor   rangelabel
# 0          1   0.19    #02C650  Muito baixo
# 1          1   0.60    #FF8300         Alto
# 2          1   0.47    #FFCD00        Médio
# 3          1   0.51    #FFCD00        Médio
# 4          1   0.78    #FF8300         Alto

# %% [markdown]
# ## risk + environmental money

# %%
# %whos DataFrame
# Out:
# Variable       Type         Data/Info
# -------------------------------------
# ambientais     DataFrame    Shape: (269, 28)
# deslizamento   DataFrame    Shape: (5570, 10)
# emendas        DataFrame    Shape: (24493, 28)
# inundacao      DataFrame    Shape: (5570, 10)
# riskadapta     DataFrame    Shape: (558, 23)
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %%
ambientais.head()
# Out:
#       Código da Emenda  Ano da Emenda  \
# 69799     202327760019           2023
# 69899     202330420002           2023
# 69942     202310740007           2023
# 69959     202320830015           2023
# 70021     202339150004           2023
#
#                                           Tipo de Emenda  \
# 69799  Emenda Individual - Transferências com Finalid...
# 69899  Emenda Individual - Transferências com Finalid...
# 69942  Emenda Individual - Transferências com Finalid...
# 69959  Emenda Individual - Transferências com Finalid...
# 70021  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 69799                      2776        ALESSANDRO MOLON               19
# 69899                      3042          ALTINEU CORTES                2
# 69942                      1074          ANDRE DE PAULA                7
# 69959                      2083        ANDRE FIGUEIREDO               15
# 70021                      3915          AROLDO MARTINS                4
#
#       Localidade de aplicação do recurso Código Município IBGE  \
# 69799                RIO DE JANEIRO (UF)        Sem informação
# 69899                   SÃO GONÇALO - RJ               3304904
# 69942                    ITAPISSUMA - PE               2607752
# 69959                        RUSSAS - CE               2311801
# 70021                        PARANÁ (UF)        Sem informação
#
#             Município  Código UF IBGE  ... Código Ação  \
# 69799  Sem informação         3300000  ...        20WM
# 69899     SÃO GONÇALO         3300000  ...        00SY
# 69942      ITAPISSUMA         2600000  ...        00T5
# 69959          RUSSAS         2300000  ...        2E87
# 70021  Sem informação         4100000  ...        2E87
#
#                                                Nome Ação  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...
# 69959  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# 70021  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
#
#       Código Plano Orçamentário  \
# 69799                      0000
# 69899                      0000
# 69942                      0000
# 69959                      0000
# 70021                      0000
#
#                                  Nome Plano Orçamentário Valor Empenhado  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...       488667.88
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...     12219069.00
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...       500000.00
# 69959  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       250000.00
# 70021  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       162920.00
#
#       Valor Liquidado Valor Pago Valor Restos A Pagar Inscritos  \
# 69799            0,00       0,00                       12805,02
# 69899       518333,00  518333,00                    11700736,00
# 69942            0,00       0,00                      143976,05
# 69959            0,00       0,00                       70400,00
# 70021            0,00       0,00                           0,00
#
#       Valor Restos A Pagar Cancelados Valor Restos A Pagar Pagos
# 69799                            0,00                  475862,86
# 69899                            0,00                       0,00
# 69942                            0,00                  356023,95
# 69959                            0,00                  179600,00
# 70021                            0,00                  162920,00
#
# [5 rows x 28 columns]

# %%
riscos = deslizamento.merge(inundacao, on='geocod_ibge', suffixes=('_deslizamento', '_inundacao'))

ambiental_cidades = ambientais.groupby('Código Município IBGE')['Valor Empenhado'].sum().reset_index()

df_final = riscos.merge(ambiental_cidades, left_on='geocod_ibge', right_on='Código Município IBGE', how='left')
df_final.shape
# Out:
# (5570, 21)

# %%
df_final.head()
# Out:
#    id_deslizamento geocod_ibge       name_deslizamento  \
# 0             2644     5200050      Abadia de Goiás/GO
# 1              754     3100104  Abadia dos Dourados/MG
# 2             2645     5200100            Abadiânia/GO
# 3              755     3100203               Abaeté/MG
# 4             2938     1500107           Abaetetuba/PA
#
#    indicator_id_deslizamento  year_deslizamento scenario_id_deslizamento  \
# 0                      60001               2015                     None
# 1                      60001               2015                     None
# 2                      60001               2015                     None
# 3                      60001               2015                     None
# 4                      60001               2015                     None
#
#    pessimist_deslizamento  value_deslizamento valuecolor_deslizamento  \
# 0                       1                0.12                 #02C650
# 1                       1                0.54                 #FFCD00
# 2                       1                0.49                 #FFCD00
# 3                       1                0.40                 #FFCD00
# 4                       1                0.48                 #FFCD00
#
#   rangelabel_deslizamento  ...          name_inundacao indicator_id_inundacao  \
# 0             Muito baixo  ...      Abadia de Goiás/GO                  60041
# 1                   Médio  ...  Abadia dos Dourados/MG                  60041
# 2                   Médio  ...            Abadiânia/GO                  60041
# 3                   Médio  ...               Abaeté/MG                  60041
# 4                   Médio  ...           Abaetetuba/PA                  60041
#
#    year_inundacao  scenario_id_inundacao pessimist_inundacao  value_inundacao  \
# 0            2015                   None                   1             0.19
# 1            2015                   None                   1             0.60
# 2            2015                   None                   1             0.47
# 3            2015                   None                   1             0.51
# 4            2015                   None                   1             0.78
#
#    valuecolor_inundacao rangelabel_inundacao Código Município IBGE  \
# 0               #02C650          Muito baixo                   NaN
# 1               #FF8300                 Alto                   NaN
# 2               #FFCD00                Médio                   NaN
# 3               #FFCD00                Médio                   NaN
# 4               #FF8300                 Alto                   NaN
#
#   Valor Empenhado
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 21 columns]

# %%
df_final = df_final.drop(columns=['id_deslizamento', 'indicator_id_deslizamento', 'year_deslizamento', 'scenario_id_deslizamento', 'pessimist_deslizamento', 'id_inundacao', 'name_inundacao', 'indicator_id_inundacao', 'year_inundacao', 'scenario_id_inundacao', 'pessimist_inundacao', 'Código Município IBGE'])
df_final.columns.tolist()
# Out:
# ['geocod_ibge',
#  'name_deslizamento',
#  'value_deslizamento',
#  'valuecolor_deslizamento',
#  'rangelabel_deslizamento',
#  'value_inundacao',
#  'valuecolor_inundacao',
#  'rangelabel_inundacao',
#  'Valor Empenhado']

# %%
df_final= df_final.rename(columns={'geocod_ibge': 'Código IBGE','name_deslizamento': 'Município','value_deslizamento': 'Índice Deslizamento','valuecolor_deslizamento': 'Cor Deslizamento','rangelabel_deslizamento': 'Label Deslizamento','value_inundacao': 'Índice Inundação','valuecolor_inundacao': 'Cor Inundação','rangelabel_inundacao': 'Label Inundação'})

df_final.head()
# Out:
#   Código IBGE               Município  Índice Deslizamento Cor Deslizamento  \
# 0     5200050      Abadia de Goiás/GO                 0.12          #02C650
# 1     3100104  Abadia dos Dourados/MG                 0.54          #FFCD00
# 2     5200100            Abadiânia/GO                 0.49          #FFCD00
# 3     3100203               Abaeté/MG                 0.40          #FFCD00
# 4     1500107           Abaetetuba/PA                 0.48          #FFCD00
#
#   Label Deslizamento  Índice Inundação Cor Inundação Label Inundação  \
# 0        Muito baixo              0.19       #02C650     Muito baixo
# 1              Médio              0.60       #FF8300            Alto
# 2              Médio              0.47       #FFCD00           Médio
# 3              Médio              0.51       #FFCD00           Médio
# 4              Médio              0.78       #FF8300            Alto
#
#    Valor Empenhado
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %% [markdown]
# ## risk per city
# following AdaptaBrasil lables

# %%
df_final
# Out:
#      Código IBGE               Município  Índice Deslizamento  \
# 0        5200050      Abadia de Goiás/GO                 0.12
# 1        3100104  Abadia dos Dourados/MG                 0.54
# 2        5200100            Abadiânia/GO                 0.49
# 3        3100203               Abaeté/MG                 0.40
# 4        1500107           Abaetetuba/PA                 0.48
# ...          ...                     ...                  ...
# 5565     2933604          Xique-Xique/BA                 0.60
# 5566     2517407               Zabelê/PB                 0.57
# 5567     3557154             Zacarias/SP                 0.12
# 5568     2114007              Zé Doca/MA                 0.61
# 5569     4219853               Zortéa/SC                 0.23
#
#      Cor Deslizamento Label Deslizamento  Índice Inundação Cor Inundação  \
# 0             #02C650        Muito baixo              0.19       #02C650
# 1             #FFCD00              Médio              0.60       #FF8300
# 2             #FFCD00              Médio              0.47       #FFCD00
# 3             #FFCD00              Médio              0.51       #FFCD00
# 4             #FFCD00              Médio              0.78       #FF8300
# ...               ...                ...               ...           ...
# 5565          #FF8300               Alto              0.72       #FF8300
# 5566          #FFCD00              Médio              0.62       #FF8300
# 5567          #02C650        Muito baixo              0.26       #A9DE00
# 5568          #FF8300               Alto              0.83       #F40000
# 5569          #A9DE00              Baixo              0.33       #A9DE00
#
#      Label Inundação  Valor Empenhado
# 0        Muito baixo              NaN
# 1               Alto              NaN
# 2              Médio              NaN
# 3              Médio              NaN
# 4               Alto              NaN
# ...              ...              ...
# 5565            Alto              NaN
# 5566            Alto              NaN
# 5567           Baixo              NaN
# 5568      Muito alto              NaN
# 5569           Baixo              NaN
#
# [5570 rows x 9 columns]

# %%
df_final['Índice Risco Médio'] =(df_final['Índice Deslizamento'] + df_final['Índice Inundação'])/2
def classificar(valor):
    if pd.isna(valor):
        return 'No data'
    if valor <= 0.19:
        return 'Very low'
    if valor <= 0.39:
        return 'Low'
    if valor <= 0.59:
        return 'Medium'
    if valor <= 0.79:
        return 'High'
    return 'Very high'

df_final['Label Risco Médio'] = df_final['Índice Risco Médio'].apply(classificar)

df_final['Label Risco Médio'].value_counts()
# Out:
# Label Risco Médio
# Medium       2116
# Low          1755
# High         1080
# Very low      399
# Very high     219
# No data         1
# Name: count, dtype: int64

# %%
df_final['Município'][df_final['Índice Risco Médio'].isna()]
# Out:
# 1773    Fernando de Noronha/PE
# Name: Município, dtype: str

# %%
emendas.head(5)
# Out:
#       Código da Emenda  Ano da Emenda  \
# 69583     202338950001           2023
# 69584     202338950002           2023
# 69585     202338950003           2023
# 69586     202338950004           2023
# 69587     202338950005           2023
#
#                                           Tipo de Emenda  \
# 69583  Emenda Individual - Transferências com Finalid...
# 69584  Emenda Individual - Transferências com Finalid...
# 69585  Emenda Individual - Transferências com Finalid...
# 69586  Emenda Individual - Transferências com Finalid...
# 69587  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda Nome do Autor da Emenda Número da emenda  \
# 69583                      3895          ABILIO SANTANA                1
# 69584                      3895          ABILIO SANTANA                2
# 69585                      3895          ABILIO SANTANA                3
# 69586                      3895          ABILIO SANTANA                4
# 69587                      3895          ABILIO SANTANA                5
#
#       Localidade de aplicação do recurso Código Município IBGE  \
# 69583              CORAÇÃO DE MARIA - BA               2908903
# 69584                        CORIBE - BA               2909109
# 69585                           MÚLTIPLO        Sem informação
# 69586                        ITATIM - BA               2916856
# 69587               SANTA TERESINHA - BA               2928505
#
#               Município  Código UF IBGE  ... Código Ação  \
# 69583  CORAÇÃO DE MARIA         2900000  ...        2E89
# 69584            CORIBE         2900000  ...        2E89
# 69585          Múltiplo         2900000  ...        2E89
# 69586            ITATIM         2900000  ...        2E90
# 69587   SANTA TERESINHA         2900000  ...        2E89
#
#                                                Nome Ação  \
# 69583  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69584  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69585  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69586  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
# 69587  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...
#
#       Código Plano Orçamentário  \
# 69583                      0000
# 69584                      0000
# 69585                      0000
# 69586                      0000
# 69587                      0000
#
#                                  Nome Plano Orçamentário Valor Empenhado  \
# 69583  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       1500000.0
# 69584  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       2000000.0
# 69585  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       8218164.0
# 69586  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...        600000.0
# 69587  INCREMENTO TEMPORARIO AO CUSTEIO DOS SERVICOS ...       1500000.0
#
#       Valor Liquidado  Valor Pago Valor Restos A Pagar Inscritos  \
# 69583      1500000,00  1500000,00                           0,00
# 69584      2000000,00  2000000,00                           0,00
# 69585      8218164,00  8218164,00                           0,00
# 69586       600000,00   600000,00                           0,00
# 69587      1500000,00  1500000,00                           0,00
#
#       Valor Restos A Pagar Cancelados Valor Restos A Pagar Pagos
# 69583                            0,00                       0,00
# 69584                            0,00                       0,00
# 69585                            0,00                       0,00
# 69586                            0,00                       0,00
# 69587                            0,00                       0,00
#
# [5 rows x 28 columns]

# %%
#How much money, how many towns
total = emendas['Valor Empenhado'].sum()
print ("earmarks total")
print (total)
# Out:
# earmarks total
# 164216823212.27002

# %%
municipal = emendas[emendas['Código Município IBGE'] != 'Sem informação']['Valor Empenhado'].sum()
print ("municipal earmarks total")
print(municipal)
# Out:
# municipal earmarks total
# 8834206204.919998

# %%
ambiental = df_final['Valor Empenhado'].sum()
print ("ambiental earmarks total")
print(ambiental)
# Out:
# ambiental earmarks total
# 54603178.18

# %%
print("Count of cities")
print({df_final['Valor Empenhado'].notna().sum()})
# Out:
# Count of cities
# {np.int64(24)}

# %% [markdown]
# Waffle for the opening visual

# %%
# %whos DataFrame
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# ambientais          DataFrame    Shape: (269, 28)
# ambiental_cidades   DataFrame    Shape: (25, 2)
# deslizamento        DataFrame    Shape: (5570, 10)
# df_final            DataFrame    Shape: (5570, 11)
# emendas             DataFrame    Shape: (24493, 28)
# inundacao           DataFrame    Shape: (5570, 10)
# riscos              DataFrame    Shape: (5570, 19)
# riskadapta          DataFrame    Shape: (558, 23)

# %%
#10000 dots
waffle = pd.DataFrame({
    'Category': ['National and state level','Municipal, other','Municipal, environmental'],
    'Dots': [10000 - round(municipal / total * 10000),round(municipal / total * 10000) - round(ambiental / total * 10000),round(ambiental / total * 10000)]
})
waffle
# Out:
#                    Category  Dots
# 0  National and state level  9462
# 1          Municipal, other   535
# 2  Municipal, environmental     3

# %% [markdown]
# ## High or very high risk

# %%
df_final
# Out:
#      Código IBGE               Município  Índice Deslizamento  \
# 0        5200050      Abadia de Goiás/GO                 0.12
# 1        3100104  Abadia dos Dourados/MG                 0.54
# 2        5200100            Abadiânia/GO                 0.49
# 3        3100203               Abaeté/MG                 0.40
# 4        1500107           Abaetetuba/PA                 0.48
# ...          ...                     ...                  ...
# 5565     2933604          Xique-Xique/BA                 0.60
# 5566     2517407               Zabelê/PB                 0.57
# 5567     3557154             Zacarias/SP                 0.12
# 5568     2114007              Zé Doca/MA                 0.61
# 5569     4219853               Zortéa/SC                 0.23
#
#      Cor Deslizamento Label Deslizamento  Índice Inundação Cor Inundação  \
# 0             #02C650        Muito baixo              0.19       #02C650
# 1             #FFCD00              Médio              0.60       #FF8300
# 2             #FFCD00              Médio              0.47       #FFCD00
# 3             #FFCD00              Médio              0.51       #FFCD00
# 4             #FFCD00              Médio              0.78       #FF8300
# ...               ...                ...               ...           ...
# 5565          #FF8300               Alto              0.72       #FF8300
# 5566          #FFCD00              Médio              0.62       #FF8300
# 5567          #02C650        Muito baixo              0.26       #A9DE00
# 5568          #FF8300               Alto              0.83       #F40000
# 5569          #A9DE00              Baixo              0.33       #A9DE00
#
#      Label Inundação  Valor Empenhado  Índice Risco Médio Label Risco Médio
# 0        Muito baixo              NaN               0.155          Very low
# 1               Alto              NaN               0.570            Medium
# 2              Médio              NaN               0.480            Medium
# 3              Médio              NaN               0.455            Medium
# 4               Alto              NaN               0.630              High
# ...              ...              ...                 ...               ...
# 5565            Alto              NaN               0.660              High
# 5566            Alto              NaN               0.595              High
# 5567           Baixo              NaN               0.190          Very low
# 5568      Muito alto              NaN               0.720              High
# 5569           Baixo              NaN               0.280               Low
#
# [5570 rows x 11 columns]

# %%
# %whos DataFrame
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# ambientais          DataFrame    Shape: (269, 28)
# ambiental_cidades   DataFrame    Shape: (25, 2)
# deslizamento        DataFrame    Shape: (5570, 10)
# df_final            DataFrame    Shape: (5570, 11)
# emendas             DataFrame    Shape: (24493, 28)
# inundacao           DataFrame    Shape: (5570, 10)
# riscos              DataFrame    Shape: (5570, 19)
# riskadapta          DataFrame    Shape: (558, 23)
# waffle              DataFrame    Shape: (3, 2)

# %%
risco_alto = df_final[df_final['Label Risco Médio'].isin(['High', 'Very high'])]
len(risco_alto)
# Out:
# 1299

# %%
risco_alto
# Out:
#      Código IBGE           Município  Índice Deslizamento Cor Deslizamento  \
# 4        1500107       Abaetetuba/PA                 0.48          #FFCD00
# 11       1500131  Abel Figueiredo/PA                 0.54          #FFCD00
# 12       3100302       Abre Campo/MG                 0.63          #FF8300
# 13       2600054     Abreu e Lima/PE                 0.99          #F40000
# 16       2100055       Açailândia/MA                 0.66          #FF8300
# ...          ...                 ...                  ...              ...
# 5560     1200708           Xapuri/AC                 0.57          #FFCD00
# 5563     2616506            Xexéu/PE                 0.62          #FF8300
# 5565     2933604      Xique-Xique/BA                 0.60          #FF8300
# 5566     2517407           Zabelê/PB                 0.57          #FFCD00
# 5568     2114007          Zé Doca/MA                 0.61          #FF8300
#
#      Label Deslizamento  Índice Inundação Cor Inundação Label Inundação  \
# 4                 Médio              0.78       #FF8300            Alto
# 11                Médio              0.67       #FF8300            Alto
# 12                 Alto              0.73       #FF8300            Alto
# 13           Muito alto              0.93       #F40000      Muito alto
# 16                 Alto              0.67       #FF8300            Alto
# ...                 ...               ...           ...             ...
# 5560              Médio              0.74       #FF8300            Alto
# 5563               Alto              0.66       #FF8300            Alto
# 5565               Alto              0.72       #FF8300            Alto
# 5566              Médio              0.62       #FF8300            Alto
# 5568               Alto              0.83       #F40000      Muito alto
#
#       Valor Empenhado  Índice Risco Médio Label Risco Médio
# 4                 NaN               0.630              High
# 11                NaN               0.605              High
# 12                NaN               0.680              High
# 13                NaN               0.960         Very high
# 16                NaN               0.665              High
# ...               ...                 ...               ...
# 5560              NaN               0.655              High
# 5563              NaN               0.640              High
# 5565              NaN               0.660              High
# 5566              NaN               0.595              High
# 5568              NaN               0.720              High
#
# [1299 rows x 11 columns]

# %% [markdown]
# ## High risk, no money

# %%
risco_alto[risco_alto['Valor Empenhado'].isna()][['Município','Índice Risco Médio','Label Risco Médio']].sort_values('Índice Risco Médio', ascending=False).head(10)
# Out:
#                         Município  Índice Risco Médio Label Risco Médio
# 3787               Pilõezinhos/PB               1.000         Very high
# 2341                    Itambé/PE               1.000         Very high
# 62                  Água Preta/PE               1.000         Very high
# 40                        Afuá/PA               1.000         Very high
# 3943                    Portel/PA               0.990         Very high
# 4174                  Ribeirão/PE               0.985         Very high
# 1879                 Gameleira/PE               0.985         Very high
# 4375  Santa Cruz do Capibaribe/PE               0.980         Very high
# 1286                     Coari/AM               0.975         Very high
# 779                     Breves/PA               0.975         Very high

# %%
#max risk versus money 
df_final.nlargest(1, 'Índice Risco Médio')[['Município', 'Índice Risco Médio', 'Valor Empenhado']]
# Out:
#    Município  Índice Risco Médio  Valor Empenhado
# 40   Afuá/PA                 1.0              NaN

# %%
df_final[df_final['Índice Risco Médio'].eq(df_final['Índice Risco Médio'].max())][['Município', 'Índice Risco Médio', 'Valor Empenhado']]
# Out:
#            Município  Índice Risco Médio  Valor Empenhado
# 40           Afuá/PA                 1.0              NaN
# 62     Água Preta/PE                 1.0              NaN
# 2341       Itambé/PE                 1.0              NaN
# 3787  Pilõezinhos/PB                 1.0              NaN

# %% [markdown]
# DF FINAL  RISCO VERSUS EMENDAS

# %%
df_final.to_csv('data/risco_emendas.csv', index=False, sep=';', encoding='utf-8-sig', decimal=',')

# %% [markdown]
# ## Reported disasters
# I DOWNLOADED Atlas Digital de Desastres (atlasdigital.mdr.gov.br) records disaster reported by a municipality since 1991.

# %%
atlas = pd.read_excel('data/dados_brutos/Atlas_1991_2025_Consolidado.xlsx')
atlas.shape
# Out:
# (76191, 70)

# %%
atlas.columns.tolist()
# Out:
# ['Protocolo_S2iD',
#  'Nome_Municipio',
#  'Sigla_UF',
#  'regiao',
#  'Data_Registro',
#  'Data_Evento',
#  'Cod_Cobrade',
#  'tipologia',
#  'descricao_tipologia',
#  'grupo_de_desastre',
#  'Cod_IBGE_Mun',
#  'Setores Censitários',
#  'Status',
#  'DH_Descricao',
#  'DH_MORTOS',
#  'DH_FERIDOS',
#  'DH_ENFERMOS',
#  'DH_DESABRIGADOS',
#  'DH_DESALOJADOS',
#  'DH_DESAPARECIDOS',
#  'DH_AFETADOS_SECA_ESTIAGEM',
#  'DH_total_danos_humanos_diretos',
#  'DH_OUTROS AFETADOS',
#  'DM_Descricao',
#  'DM_Uni Habita Danificadas',
#  'DM_Uni Habita Destruidas',
#  'DM_Uni Habita Valor',
#  'DM_Inst Saúde Danificadas',
#  'DM_Inst Saúde Destruidas',
#  'DM_Inst Saúde Valor',
#  'DM_Inst Ensino Danificadas',
#  'DM_Inst Ensino Destruidas',
#  'DM_Inst Ensino Valor',
#  'DM_Inst Serviços Danificadas',
#  'DM_Inst Serviços Destruidas',
#  'DM_Inst Serviços Valor',
#  'DM_Inst Comuni Danificadas',
#  'DM_Inst Comuni Destruidas',
#  'DM_Inst Comuni Valor',
#  'DM_Obras de Infra Danificadas',
#  'DM_Obras de Infra Destruidas',
#  'DM_Obras de Infra Valor',
#  'DM_total_danos_materiais',
#  'DA_Descricao',
#  'DA_Polui/cont da água',
#  'DA_Polui/cont do ar',
#  'DA_Polui/cont do solo',
#  'DA_Dimi/exauri hídrico',
#  "DA_Incêndi parques/APA's/APP's",
#  'PEPL_Descricao',
#  'PEPL_Assis_méd e emergên(R$)',
#  'PEPL_Abast de água pot(R$)',
#  'PEPL_sist de esgotos sanit(R$)',
#  'PEPL_Sis limp e rec lixo (R$)',
#  'PEPL_Sis cont pragas (R$)',
#  'PEPL_distrib energia (R$)',
#  'PEPL_Telecomunicações (R$)',
#  'PEPL_Tran loc/reg/l_curso (R$)',
#  'PEPL_Distrib combustíveis(R$)',
#  'PEPL_Segurança pública (R$)',
#  'PEPL_Ensino (R$)',
#  'PEPL_total_publico',
#  'PEPR_Descricao',
#  'PEPR_Agricultura (R$)',
#  'PEPR_Pecuária (R$)',
#  'PEPR_Indústria (R$)',
#  'PEPR_Comércio (R$)',
#  'PEPR_Serviços (R$)',
#  'PEPR_total_privado',
#  'PE_PLePR']

# %%
atlas['descricao_tipologia'].unique()
# Out:
# <ArrowStringArray>
# [                'Estiagem e Seca',                      'Enxurradas',
#             'Vendavais e Ciclones',                      'Inundações',
#                          'Granizo',             'Doenças infecciosas',
#                          'Tornado',                          'Erosão',
#                      'Alagamentos',              'Movimento de Massa',
#                           'Outros',              'Incêndio Florestal',
#                  'Chuvas Intensas',                    'Onda de Frio',
#  'Rompimento/Colapso de barragens',   'Onda de Calor e Baixa Umidade']
# Length: 16, dtype: str

# %% [markdown]
# Geo-hydrological: enxurrada, inundacoes, alagamentos, movimentos de massa, chuvas intensas. Year: Data Evento

# %%
tipos = ['Enxurradas', 'Inundações', 'Alagamentos', 'Movimento de Massa', 'Chuvas Intensas']
desastres = atlas[atlas['descricao_tipologia'].isin(tipos)].copy()
desastres['Ano_Evento'] = pd.to_datetime(desastres['Data_Evento']).dt.year
desastres.head()
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='Task-431' coro=<_async_in_context.<locals>.run_in_context() done, defined at /Users/gqueiroz/.venvs/lede/lib/python3.13/site-packages/ipykernel/utils.py:57> wait_for=<Task pending name='Task-432' coro=<Kernel.shell_main() running at /Users/gqueiroz/.venvs/lede/lib/python3.13/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/gqueiroz/.venvs/lede/lib/python3.13/site-packages/zmq/eventloop/zmqstream.py:563]>
# /Users/gqueiroz/.venvs/lede/lib/python3.13/site-packages/pandas/core/internals/blocks.py:650: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   return type(self)(values, placement=self._mgr_locs, ndim=self.ndim, refs=refs)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-432' coro=<Kernel.shell_main() running at /Users/gqueiroz/.venvs/lede/lib/python3.13/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]>
#                  Protocolo_S2iD           Nome_Municipio Sigla_UF  \
# 8   AC-P-1200401-12200-19910121               Rio Branco       AC
# 26  RJ-P-3305802-12200-19910130              Teresópolis       RJ
# 30  ES-P-3201209-12100-19910214  Cachoeiro de Itapemirim       ES
# 57  PR-R-4125902-12200-19910221      São Pedro do Paraná       PR
# 65  MT-J-5107859-12200-19910226    São Félix do Araguaia       MT
#
#           regiao Data_Registro Data_Evento  Cod_Cobrade  tipologia  \
# 8          Norte    1991-01-21  1991-01-21        12200          2
# 26       Sudeste    1991-01-30  1991-01-30        12200          2
# 30       Sudeste    1991-02-14  1991-02-14        12100          7
# 57           Sul    1991-02-21  1991-02-21        12200          2
# 65  Centro-oeste    1991-02-26  1991-02-26        12200          2
#
#    descricao_tipologia grupo_de_desastre  ...  PEPL_total_publico  \
# 8           Enxurradas       Hidrológico  ...                 0.0
# 26          Enxurradas       Hidrológico  ...                 0.0
# 30          Inundações       Hidrológico  ...                 0.0
# 57          Enxurradas       Hidrológico  ...                 0.0
# 65          Enxurradas       Hidrológico  ...                 0.0
#
#    PEPR_Descricao PEPR_Agricultura (R$) PEPR_Pecuária (R$)  \
# 8             NaN                   0.0                0.0
# 26            NaN                   0.0                0.0
# 30            NaN                   0.0                0.0
# 57            NaN                   0.0                0.0
# 65            NaN                   0.0                0.0
#
#     PEPR_Indústria (R$)  PEPR_Comércio (R$)  PEPR_Serviços (R$)  \
# 8                   0.0                 0.0                 0.0
# 26                  0.0                 0.0                 0.0
# 30                  0.0                 0.0                 0.0
# 57                  0.0                 0.0                 0.0
# 65                  0.0                 0.0                 0.0
#
#     PEPR_total_privado  PE_PLePR  Ano_Evento
# 8                  0.0       0.0        1991
# 26                 0.0       0.0        1991
# 30                 0.0       0.0        1991
# 57                 0.0       0.0        1991
# 65                 0.0       0.0        1991
#
# [5 rows x 71 columns]

# %%
desastres.shape
# Out:
# (29353, 71)

# %% [markdown]
# Totals since 1991, deaths and material damage

# %%
desastres['DH_MORTOS'].sum(), desastres['DM_total_danos_materiais'].sum()
# Out:
# (np.int64(4612), np.float64(84066580755.98))

# %% [markdown]
# Deaths per year

# %%
mortos = desastres.groupby('Ano_Evento')['DH_MORTOS'].sum().reset_index()
mortos.head()
# Out:
#    Ano_Evento  DH_MORTOS
# 0        1991         36
# 1        1992         11
# 2        1993         16
# 3        1994          4
# 4        1995         31

# %%
mortos
# Out:
#     Ano_Evento  DH_MORTOS
# 0         1991         36
# 1         1992         11
# 2         1993         16
# 3         1994          4
# 4         1995         31
# 5         1996         12
# 6         1997          8
# 7         1998          7
# 8         1999          7
# 9         2000         53
# 10        2001         65
# 11        2002         86
# 12        2003         91
# 13        2004        190
# 14        2005        107
# 15        2006        143
# 16        2007        114
# 17        2008        196
# 18        2009        262
# 19        2010        339
# 20        2011        947
# 21        2012         82
# 22        2013        132
# 23        2014         63
# 24        2015         47
# 25        2016         56
# 26        2017         48
# 27        2018         50
# 28        2019         89
# 29        2020        165
# 30        2021         58
# 31        2022        600
# 32        2023        171
# 33        2024        263
# 34        2025         63

# %%
DESASTRES E MORTOS CSV

# %%
desastres.to_csv('data/desastres.csv', index=False, sep=';', encoding='utf-8-sig', decimal=',')
mortos.to_csv('data/mortos.csv', index=False)

# %% [markdown]
# ## Events and deaths since 2023

# %%
desastres
# Out:
#                     Protocolo_S2iD           Nome_Municipio Sigla_UF  \
# 8      AC-P-1200401-12200-19910121               Rio Branco       AC
# 26     RJ-P-3305802-12200-19910130              Teresópolis       RJ
# 30     ES-P-3201209-12100-19910214  Cachoeiro de Itapemirim       ES
# 57     PR-R-4125902-12200-19910221      São Pedro do Paraná       PR
# 65     MT-J-5107859-12200-19910226    São Félix do Araguaia       MT
# ...                            ...                      ...      ...
# 76186  SC-F-4212106-13214-20251231                 Palmitos       SC
# 76187  MG-F-3147907-13214-20251231                   Passos       MG
# 76188  SC-F-4212304-13214-20251231              Paulo Lopes       SC
# 76189  SC-F-4216305-13214-20251231         São João Batista       SC
# 76190  SC-F-4219606-13214-20251231                Xavantina       SC
#
#              regiao Data_Registro Data_Evento  Cod_Cobrade  tipologia  \
# 8             Norte    1991-01-21  1991-01-21        12200          2
# 26          Sudeste    1991-01-30  1991-01-30        12200          2
# 30          Sudeste    1991-02-14  1991-02-14        12100          7
# 57              Sul    1991-02-21  1991-02-21        12200          2
# 65     Centro-oeste    1991-02-26  1991-02-26        12200          2
# ...             ...           ...         ...          ...        ...
# 76186           Sul    2026-01-02  2025-12-31        13214         13
# 76187       Sudeste    2026-01-06  2025-12-31        13214         13
# 76188           Sul    2026-01-07  2025-12-31        13214         13
# 76189           Sul    2026-01-01  2025-12-31        13214         13
# 76190           Sul    2026-01-19  2025-12-31        13214         13
#
#       descricao_tipologia grupo_de_desastre  ...  PEPL_total_publico  \
# 8              Enxurradas       Hidrológico  ...                 0.0
# 26             Enxurradas       Hidrológico  ...                 0.0
# 30             Inundações       Hidrológico  ...                 0.0
# 57             Enxurradas       Hidrológico  ...                 0.0
# 65             Enxurradas       Hidrológico  ...                 0.0
# ...                   ...               ...  ...                 ...
# 76186     Chuvas Intensas       Hidrológico  ...             90000.0
# 76187     Chuvas Intensas       Hidrológico  ...            620000.0
# 76188     Chuvas Intensas       Hidrológico  ...                 0.0
# 76189     Chuvas Intensas       Hidrológico  ...            350000.0
# 76190     Chuvas Intensas       Hidrológico  ...           2500000.0
#
#                                           PEPR_Descricao  \
# 8                                                    NaN
# 26                                                   NaN
# 30                                                   NaN
# 57                                                   NaN
# 65                                                   NaN
# ...                                                  ...
# 76186  As chuvas intensas e o elevado escoamento supe...
# 76187  As intensas chuvas inviabilizaram as estradas ...
# 76188                                                NaN
# 76189  Com efeito do desastre ocasionou a interrupção...
# 76190                      Não houve prejuizos privados.
#
#       PEPR_Agricultura (R$) PEPR_Pecuária (R$)  PEPR_Indústria (R$)  \
# 8                       0.0                0.0                  0.0
# 26                      0.0                0.0                  0.0
# 30                      0.0                0.0                  0.0
# 57                      0.0                0.0                  0.0
# 65                      0.0                0.0                  0.0
# ...                     ...                ...                  ...
# 76186              100000.0            80000.0                  0.0
# 76187               10000.0            10000.0                  0.0
# 76188                   0.0                0.0                  0.0
# 76189              100000.0                0.0                  0.0
# 76190                   0.0                0.0                  0.0
#
#        PEPR_Comércio (R$)  PEPR_Serviços (R$)  PEPR_total_privado   PE_PLePR  \
# 8                     0.0                 0.0                 0.0        0.0
# 26                    0.0                 0.0                 0.0        0.0
# 30                    0.0                 0.0                 0.0        0.0
# 57                    0.0                 0.0                 0.0        0.0
# 65                    0.0                 0.0                 0.0        0.0
# ...                   ...                 ...                 ...        ...
# 76186                 0.0             90000.0            270000.0   360000.0
# 76187                 0.0                 0.0             20000.0   640000.0
# 76188                 0.0                 0.0                 0.0        0.0
# 76189                 0.0                 0.0            100000.0   450000.0
# 76190                 0.0                 0.0                 0.0  2500000.0
#
#        Ano_Evento
# 8            1991
# 26           1991
# 30           1991
# 57           1991
# 65           1991
# ...           ...
# 76186        2025
# 76187        2025
# 76188        2025
# 76189        2025
# 76190        2025
#
# [29353 rows x 71 columns]

# %%
recentes = desastres[desastres['Ano_Evento'] >= 2023]

recentes['DH_MORTOS'].sum()
# Out:
# np.int64(497)

# %%
eventos_municipio = recentes.groupby('Cod_IBGE_Mun').agg(Nome_Municipio=('Nome_Municipio', 'first'), Sigla_UF=('Sigla_UF', 'first'), Eventos=('Nome_Municipio', 'size')).reset_index()
eventos_municipio.sort_values('Eventos', ascending=False).head(10)
# Out:
#       Cod_IBGE_Mun  Nome_Municipio Sigla_UF  Eventos
# 465        2607208         Ipojuca       PE       47
# 873        3136702    Juiz de Fora       MG       27
# 1578       4210100           Mafra       SC       24
# 2226       5005806         Nioaque       MS       23
# 149        1505304       Oriximiná       PA       21
# 376        2313807     Uruburetama       CE       17
# 446        2600054    Abreu e Lima       PE       16
# 1474       4202438  Bocaina do Sul       SC       16
# 2204       5002704    Campo Grande       MS       16
# 1483       4202909         Brusque       SC       15

# %% [markdown]
# Ipojuca

# %%
recentes[recentes['Cod_IBGE_Mun'].astype(str) == '2607208']['descricao_tipologia'].value_counts()
# Out:
# descricao_tipologia
# Movimento de Massa    43
# Chuvas Intensas        2
# Alagamentos            2
# Name: count, dtype: int64

# %% [markdown]
# ## Events x environmental money

# %%
eventos_emendas = eventos_municipio.merge(ambiental_cidades, left_on='Cod_IBGE_Mun', right_on='Código Município IBGE', how='left')
eventos_emendas['Valor Empenhado'] = eventos_emendas['Valor Empenhado'].fillna(0)
eventos_emendas.sort_values('Eventos', ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 eventos_emendas = eventos_municipio.merge(ambiental_cidades, left_on='Cod_IBGE_Mun', right_on='Código Município IBGE', how='left')
#       2 eventos_emendas['Valor Empenhado'] = eventos_emendas['Valor Empenhado'].fillna(0)
#       3 eventos_emendas.sort_values('Eventos', ascending=False).head(10)
#
# File ~/.venvs/lede/lib/python3.13/site-packages/pandas/core/frame.py:12900, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   12896         self._check_copy_deprecation(copy)
#   12897
#   12898         from pandas.core.reshape.merge import merge
#   12899
# > 12900         return merge(
#   12901             self,
#   12902             right,
#   12903             how=how,
#
# File ~/.venvs/lede/lib/python3.13/site-packages/pandas/core/reshape/merge.py:385, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     371     return _cross_merge(
#     372         left_df,
#     373         right_df,
#    (...)    382         validate=validate,
#     383     )
#     384 else:
# --> 385     op = _MergeOperation(
#     386         left_df,
#     387         right_df,
#     388         how=how,
#     389         on=on,
#     390         left_on=left_on,
#     391         right_on=right_on,
#     392         left_index=left_index,
#     393         right_index=right_index,
#     394         sort=sort,
#     395         suffixes=suffixes,
#     396         indicator=indicator,
#     397         validate=validate,
#     398     )
#     399     return op.get_result()
#
# File ~/.venvs/lede/lib/python3.13/site-packages/pandas/core/reshape/merge.py:1031, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#    1027 self._validate_tolerance(self.left_join_keys)
#    1029 # validate the merge keys dtypes. We may need to coerce
#    1030 # to avoid incompatible dtypes
# -> 1031 self._maybe_coerce_merge_keys()
#    1033 # If argument passed to validate,
#    1034 # check if columns specified as unique
#    1035 # are in fact unique.
#    1036 if validate is not None:
#
# File ~/.venvs/lede/lib/python3.13/site-packages/pandas/core/reshape/merge.py:1835, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1829     # unless we are merging non-string-like with string-like
#    1830     elif (
#    1831         inferred_left in string_types and inferred_right not in string_types
#    1832     ) or (
#    1833         inferred_right in string_types and inferred_left not in string_types
#    1834     ):
# -> 1835         raise ValueError(msg)
#    1837 # datetimelikes must match exactly
#    1838 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on int64 and str columns for key 'Cod_IBGE_Mun'. If you wish to proceed you should use pd.concat

# %%
eventos_emendas = eventos_municipio.merge(
    ambiental_cidades,
    left_on=eventos_municipio['Cod_IBGE_Mun'].astype(str),
    right_on=ambiental_cidades['Código Município IBGE'].astype(str),
    how='left')
eventos_emendas['Valor Empenhado'] = eventos_emendas['Valor Empenhado'].fillna(0)
eventos_emendas.sort_values('Eventos', ascending=False).head(10)
# Out:
#         key_0  Cod_IBGE_Mun  Nome_Municipio Sigla_UF  Eventos  \
# 465   2607208       2607208         Ipojuca       PE       47
# 873   3136702       3136702    Juiz de Fora       MG       27
# 1578  4210100       4210100           Mafra       SC       24
# 2226  5005806       5005806         Nioaque       MS       23
# 149   1505304       1505304       Oriximiná       PA       21
# 376   2313807       2313807     Uruburetama       CE       17
# 446   2600054       2600054    Abreu e Lima       PE       16
# 1474  4202438       4202438  Bocaina do Sul       SC       16
# 2204  5002704       5002704    Campo Grande       MS       16
# 1483  4202909       4202909         Brusque       SC       15
#
#      Código Município IBGE  Valor Empenhado
# 465                    NaN              0.0
# 873                    NaN              0.0
# 1578                   NaN              0.0
# 2226                   NaN              0.0
# 149                    NaN              0.0
# 376                    NaN              0.0
# 446                    NaN              0.0
# 1474                   NaN              0.0
# 2204                   NaN              0.0
# 1483               4202909         340000.0

# %% [markdown]
# Who had events and also got money?

# %%
eventos_emendas[eventos_emendas['Valor Empenhado'] > 0].sort_values('Eventos', ascending=False)
# Out:
#         key_0  Cod_IBGE_Mun           Nome_Municipio Sigla_UF  Eventos  \
# 1483  4202909       4202909                  Brusque       SC       15
# 1787  4304606       4304606                   Canoas       RS        7
# 1863  4307708       4307708                   Esteio       RS        5
# 1864  4307807       4307807                  Estrela       RS        4
# 1176  3303906       3303906               Petrópolis       RJ        4
# 412   2408102       2408102                    Natal       RN        4
# 1520  4205555       4205555             Frei Rogério       SC        3
# 1197  3305802       3305802              Teresópolis       RJ        3
# 1187  3304904       3304904              São Gonçalo       RJ        2
# 2251  5103403       5103403                   Cuiabá       MT        2
# 2281  5108402       5108402            Várzea Grande       MT        2
# 1182  3304557       3304557           Rio de Janeiro       RJ        2
# 1150  3301009       3301009    Campos dos Goytacazes       RJ        2
# 470   2607901       2607901  Jaboatão dos Guararapes       PE        2
# 469   2607752       2607752               Itapissuma       PE        1
# 439   2504009       2504009           Campina Grande       PB        1
# 342   2304400       2304400                Fortaleza       CE        1
#
#      Código Município IBGE  Valor Empenhado
# 1483               4202909        340000.00
# 1787               4304606        200000.00
# 1863               4307708        150000.00
# 1864               4307807        200000.00
# 1176               3303906       1863800.00
# 412                2408102       5750000.00
# 1520               4205555        382000.00
# 1197               3305802       1000000.00
# 1187               3304904      12219069.00
# 2251               5103403       2000000.00
# 2281               5108402      14000000.00
# 1182               3304557       4116150.00
# 1150               3301009       1268737.18
# 470                2607901       5000000.00
# 469                2607752        500000.00
# 439                2504009        500000.00
# 342                2304400        250000.00

# %% [markdown]
# ## Deaths since 2023 x money

# %%
# %whos DataFrame
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# ambientais          DataFrame    Shape: (269, 28)
# ambiental_cidades   DataFrame    Shape: (25, 2)
# atlas               DataFrame    Shape: (76191, 70)
# desastres           DataFrame    Shape: (29353, 71)
# deslizamento        DataFrame    Shape: (5570, 10)
# df_final            DataFrame    Shape: (5570, 11)
# emendas             DataFrame    Shape: (24493, 28)
# eventos_emendas     DataFrame    Shape: (2317, 7)
# eventos_municipio   DataFrame    Shape: (2317, 4)
# inundacao           DataFrame    Shape: (5570, 10)
# mortos              DataFrame    Shape: (35, 2)
# recentes            DataFrame    Shape: (5779, 71)
# risco_alto          DataFrame    Shape: (1299, 11)
# riscos              DataFrame    Shape: (5570, 19)
# riskadapta          DataFrame    Shape: (558, 23)
# waffle              DataFrame    Shape: (3, 2)

# %%
recentes
# Out:
#                     Protocolo_S2iD       Nome_Municipio Sigla_UF    regiao  \
# 62115  BA-F-2907806-13214-20230101        Cícero Dantas       BA  Nordeste
# 62116  MG-F-3153400-13214-20230101  Presidente Olegário       MG   Sudeste
# 62117  MG-F-3130903-13214-20230101              Inhapim       MG   Sudeste
# 62118  MG-F-3128402-13214-20230101              Guarani       MG   Sudeste
# 62119  MG-F-3155801-13214-20230101            Rio Pomba       MG   Sudeste
# ...                            ...                  ...      ...       ...
# 76186  SC-F-4212106-13214-20251231             Palmitos       SC       Sul
# 76187  MG-F-3147907-13214-20251231               Passos       MG   Sudeste
# 76188  SC-F-4212304-13214-20251231          Paulo Lopes       SC       Sul
# 76189  SC-F-4216305-13214-20251231     São João Batista       SC       Sul
# 76190  SC-F-4219606-13214-20251231            Xavantina       SC       Sul
#
#             Data_Registro Data_Evento  Cod_Cobrade  tipologia  \
# 62115 2023-01-03 15:14:21  2023-01-01        13214         13
# 62116 2023-01-18 17:06:06  2023-01-01        13214         13
# 62117 2023-01-19 11:02:49  2023-01-01        13214         13
# 62118 2023-01-05 11:25:07  2023-01-01        13214         13
# 62119 2023-01-05 13:28:49  2023-01-01        13214         13
# ...                   ...         ...          ...        ...
# 76186 2026-01-02 00:00:00  2025-12-31        13214         13
# 76187 2026-01-06 00:00:00  2025-12-31        13214         13
# 76188 2026-01-07 00:00:00  2025-12-31        13214         13
# 76189 2026-01-01 00:00:00  2025-12-31        13214         13
# 76190 2026-01-19 00:00:00  2025-12-31        13214         13
#
#       descricao_tipologia grupo_de_desastre  ...  PEPL_total_publico  \
# 62115     Chuvas Intensas       Hidrológico  ...             52000.0
# 62116     Chuvas Intensas       Hidrológico  ...            150000.0
# 62117     Chuvas Intensas       Hidrológico  ...            700000.0
# 62118     Chuvas Intensas       Hidrológico  ...                 0.0
# 62119     Chuvas Intensas       Hidrológico  ...              2000.0
# ...                   ...               ...  ...                 ...
# 76186     Chuvas Intensas       Hidrológico  ...             90000.0
# 76187     Chuvas Intensas       Hidrológico  ...            620000.0
# 76188     Chuvas Intensas       Hidrológico  ...                 0.0
# 76189     Chuvas Intensas       Hidrológico  ...            350000.0
# 76190     Chuvas Intensas       Hidrológico  ...           2500000.0
#
#                                           PEPR_Descricao  \
# 62115  ATÉ O MOMENTO NÃO AVALIADO DEVIDO A PRECARIEDA...
# 62116  PREJUÍZOS NA AGRICULTURA SENDO ESTA A FRUTICUL...
# 62117  COM QUEDAS DE ESTRAS E PONTES IMPOSSIBILITOU Q...
# 62118  Devido às chuvas intensas ocorridas no municíp...
# 62119  Devido às chuvas intensas ocorridas no municíp...
# ...                                                  ...
# 76186  As chuvas intensas e o elevado escoamento supe...
# 76187  As intensas chuvas inviabilizaram as estradas ...
# 76188                                                NaN
# 76189  Com efeito do desastre ocasionou a interrupção...
# 76190                      Não houve prejuizos privados.
#
#       PEPR_Agricultura (R$) PEPR_Pecuária (R$)  PEPR_Indústria (R$)  \
# 62115                   0.0                0.0                  0.0
# 62116              100000.0          2000000.0                  0.0
# 62117              600000.0           450000.0                  0.0
# 62118                   0.0                0.0                  0.0
# 62119                   0.0                0.0                  0.0
# ...                     ...                ...                  ...
# 76186              100000.0            80000.0                  0.0
# 76187               10000.0            10000.0                  0.0
# 76188                   0.0                0.0                  0.0
# 76189              100000.0                0.0                  0.0
# 76190                   0.0                0.0                  0.0
#
#        PEPR_Comércio (R$)  PEPR_Serviços (R$)  PEPR_total_privado   PE_PLePR  \
# 62115                 0.0                 0.0                 0.0    52000.0
# 62116                 0.0                 0.0           2100000.0  2250000.0
# 62117                 0.0                 0.0           1050000.0  1750000.0
# 62118                 0.0                 0.0                 0.0        0.0
# 62119                 0.0                 0.0                 0.0     2000.0
# ...                   ...                 ...                 ...        ...
# 76186                 0.0             90000.0            270000.0   360000.0
# 76187                 0.0                 0.0             20000.0   640000.0
# 76188                 0.0                 0.0                 0.0        0.0
# 76189                 0.0                 0.0            100000.0   450000.0
# 76190                 0.0                 0.0                 0.0  2500000.0
#
#        Ano_Evento
# 62115        2023
# 62116        2023
# 62117        2023
# 62118        2023
# 62119        2023
# ...           ...
# 76186        2025
# 76187        2025
# 76188        2025
# 76189        2025
# 76190        2025
#
# [5779 rows x 71 columns]

# %%
mortos = recentes.groupby('Cod_IBGE_Mun', as_index=False).agg(Nome_Municipio=('Nome_Municipio', 'first'), Sigla_UF=('Sigla_UF', 'first'), DH_MORTOS=('DH_MORTOS', 'sum'))
mortos.head()
# Out:
#    Cod_IBGE_Mun         Nome_Municipio Sigla_UF  DH_MORTOS
# 0       1100015  Alta Floresta D`Oeste       RO          0
# 1       1100023              Ariquemes       RO          0
# 2       1100049                 Cacoal       RO          0
# 3       1100056             Cerejeiras       RO          0
# 4       1100114                   Jaru       RO          0

# %%
mortos['Cod_IBGE_Mun'] = mortos['Cod_IBGE_Mun'].astype(str)

# %%
mortos = mortos.merge(ambiental_cidades, left_on='Cod_IBGE_Mun', right_on='Código Município IBGE', how='left')
mortos['Valor Empenhado'] = mortos['Valor Empenhado'].fillna(0)
mortos.sort_values('DH_MORTOS', ascending=False).head(10)
# Out:
#      Cod_IBGE_Mun   Nome_Municipio Sigla_UF  DH_MORTOS Código Município IBGE  \
# 1301      3550704    São Sebastião       SP         56                   NaN
# 1787      4304606           Canoas       RS         31               4304606
# 1124      3203403    Mimoso do Sul       ES         18                   NaN
# 1833      4306205  Cruzeiro do Sul       RS         17                   NaN
# 1969      4312609            Muçum       RS         14                   NaN
# 2049      4315800       Roca Sales       RS         14                   NaN
# 1752      4302105  Bento Gonçalves       RS         11                   NaN
# 2099      4318705     São Leopoldo       RS         11                   NaN
# 844       3131307         Ipatinga       MG         10                   NaN
# 1802      4305108    Caxias do Sul       RS          9                   NaN
#
#       Valor Empenhado
# 1301              0.0
# 1787         200000.0
# 1124              0.0
# 1833              0.0
# 1969              0.0
# 2049              0.0
# 1752              0.0
# 2099              0.0
# 844               0.0
# 1802              0.0

# %%
#city with death and no money 
mortos[mortos['DH_MORTOS'] > 0]['Valor Empenhado'].eq(0).value_counts()
# Out:
# Valor Empenhado
# True     165
# False      7
# Name: count, dtype: int64

# %%
CSV EVENTOS X EMENDAS SALVO

# %%
eventos_emendas.to_csv('data/eventos_emendas.csv', index=False, sep=';', encoding='utf-8-sig', decimal=',')

# %%
eventos_emendas
# Out:
#         key_0  Cod_IBGE_Mun         Nome_Municipio Sigla_UF  Eventos  \
# 0     1100015       1100015  Alta Floresta D`Oeste       RO        1
# 1     1100023       1100023              Ariquemes       RO        1
# 2     1100049       1100049                 Cacoal       RO        2
# 3     1100056       1100056             Cerejeiras       RO        1
# 4     1100114       1100114                   Jaru       RO        4
# ...       ...           ...                    ...      ...      ...
# 2312  5220686       5220686             Simolândia       GO        1
# 2313  5221577       5221577               Uirapuru       GO        2
# 2314  5221700       5221700                 Uruana       GO        1
# 2315  5221858       5221858    Valparaíso de Goiás       GO        1
# 2316  5300108       5300108               Brasília       DF        1
#
#      Código Município IBGE  Valor Empenhado
# 0                      NaN              0.0
# 1                      NaN              0.0
# 2                      NaN              0.0
# 3                      NaN              0.0
# 4                      NaN              0.0
# ...                    ...              ...
# 2312                   NaN              0.0
# 2313                   NaN              0.0
# 2314                   NaN              0.0
# 2315                   NaN              0.0
# 2316                   NaN              0.0
#
# [2317 rows x 7 columns]

# %%
##scatter Flourish
scatter = eventos_emendas.copy()
scatter['name'] = scatter['Nome_Municipio'] + '/' + scatter['Sigla_UF']
scatter['Grupo'] = (scatter['Valor Empenhado'] > 0).map({True: 'Received', False: 'No earmark'})

scatter = scatter[['name', 'Eventos', 'Valor Empenhado', 'Grupo']]
scatter.to_csv('data/scatter_eventos_valor.csv', index=False)

len(scatter), (scatter['Grupo'] == 'Received').sum()
# Out:
# (2317, np.int64(17))

# %% [markdown]
# ## Money follow risk?

# %%
# %whos DataFrame
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# ambientais          DataFrame    Shape: (269, 28)
# ambiental_cidades   DataFrame    Shape: (25, 2)
# atlas               DataFrame    Shape: (76191, 70)
# desastres           DataFrame    Shape: (29353, 71)
# deslizamento        DataFrame    Shape: (5570, 10)
# df_final            DataFrame    Shape: (5570, 11)
# emendas             DataFrame    Shape: (24493, 28)
# eventos_emendas     DataFrame    Shape: (2317, 7)
# eventos_municipio   DataFrame    Shape: (2317, 4)
# inundacao           DataFrame    Shape: (5570, 10)
# mortos              DataFrame    Shape: (2317, 6)
# recentes            DataFrame    Shape: (5779, 71)
# risco_alto          DataFrame    Shape: (1299, 11)
# riscos              DataFrame    Shape: (5570, 19)
# riskadapta          DataFrame    Shape: (558, 23)
# scatter             DataFrame    Shape: (2317, 4)
# waffle              DataFrame    Shape: (3, 2)

# %%
df_final['Código IBGE'] = df_final['Código IBGE'].astype(str)
eventos_municipio['Cod_IBGE_Mun'] = eventos_municipio['Cod_IBGE_Mun'].astype(str)

# %%
correlacao = df_final.merge(eventos_municipio[['Cod_IBGE_Mun', 'Eventos']], left_on='Código IBGE', right_on='Cod_IBGE_Mun', how='left')
correlacao = correlacao[['Valor Empenhado', 'Índice Deslizamento', 'Índice Inundação', 'Índice Risco Médio', 'Eventos']]
correlacao = correlacao.fillna(0)
matriz = correlacao.corr(method='spearman').round(2)
matriz.style.background_gradient(cmap='RdBu_r', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_86de0_row0_col0, #T_86de0_row1_col1, #T_86de0_row2_col2, #T_86de0_row3_col3, #T_86de0_row4_col4 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_86de0_row0_col1, #T_86de0_row0_col4, #T_86de0_row1_col0, #T_86de0_row4_col0 {
#   background-color: #f9f0eb;
#   color: #000000;
# }
# #T_86de0_row0_col2, #T_86de0_row2_col0 {
#   background-color: #f8f3f0;
#   color: #000000;
# }
# #T_86de0_row0_col3, #T_86de0_row3_col0 {
#   background-color: #f8f1ed;
#   color: #000000;
# }
# #T_86de0_row1_col2, #T_86de0_row2_col1 {
#   background-color: #8a0b25;
#   color: #f1f1f1;
# }
# #T_86de0_row1_col3, #T_86de0_row3_col1 {
#   background-color: #700320;
#   color: #f1f1f1;
# }
# #T_86de0_row1_col4, #T_86de0_row4_col1 {
#   background-color: #f5f6f7;
#   color: #000000;
# }
# #T_86de0_row2_col3, #T_86de0_row3_col2 {
#   background-color: #6d0220;
#   color: #f1f1f1;
# }
# #T_86de0_row2_col4, #T_86de0_row4_col2 {
#   background-color: #edf2f5;
#   color: #000000;
# }
# #T_86de0_row3_col4, #T_86de0_row4_col3 {
#   background-color: #f2f5f6;
#   color: #000000;
# }
# </style>
# <table id="T_86de0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86de0_level0_col0" class="col_heading level0 col0" >Valor Empenhado</th>
#       <th id="T_86de0_level0_col1" class="col_heading level0 col1" >Índice Deslizamento</th>
#       <th id="T_86de0_level0_col2" class="col_heading level0 col2" >Índice Inundação</th>
#       <th id="T_86de0_level0_col3" class="col_heading level0 col3" >Índice Risco Médio</th>
#       <th id="T_86de0_level0_col4" class="col_heading level0 col4" >Eventos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86de0_level0_row0" class="row_heading level0 row0" >Valor Empenhado</th>
#       <td id="T_86de0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_86de0_row0_col1" class="data row0 col1" >0.050000</td>
#       <td id="T_86de0_row0_col2" class="data row0 col2" >0.030000</td>
#       <td id="T_86de0_row0_col3" class="data row0 col3" >0.040000</td>
#       <td id="T_86de0_row0_col4" class="data row0 col4" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_86de0_level0_row1" class="row_heading level0 row1" >Índice Deslizamento</th>
#       <td id="T_86de0_row1_col0" class="data row1 col0" >0.050000</td>
#       <td id="T_86de0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_86de0_row1_col2" class="data row1 col2" >0.900000</td>
#       <td id="T_86de0_row1_col3" class="data row1 col3" >0.970000</td>
#       <td id="T_86de0_row1_col4" class="data row1 col4" >-0.010000</td>
#     </tr>
#     <tr>
#       <th id="T_86de0_level0_row2" class="row_heading level0 row2" >Índice Inundação</th>
#       <td id="T_86de0_row2_col0" class="data row2 col0" >0.030000</td>
#       <td id="T_86de0_row2_col1" class="data row2 col1" >0.900000</td>
#       <td id="T_86de0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_86de0_row2_col3" class="data row2 col3" >0.980000</td>
#       <td id="T_86de0_row2_col4" class="data row2 col4" >-0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_86de0_level0_row3" class="row_heading level0 row3" >Índice Risco Médio</th>
#       <td id="T_86de0_row3_col0" class="data row3 col0" >0.040000</td>
#       <td id="T_86de0_row3_col1" class="data row3 col1" >0.970000</td>
#       <td id="T_86de0_row3_col2" class="data row3 col2" >0.980000</td>
#       <td id="T_86de0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_86de0_row3_col4" class="data row3 col4" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_86de0_level0_row4" class="row_heading level0 row4" >Eventos</th>
#       <td id="T_86de0_row4_col0" class="data row4 col0" >0.050000</td>
#       <td id="T_86de0_row4_col1" class="data row4 col1" >-0.010000</td>
#       <td id="T_86de0_row4_col2" class="data row4 col2" >-0.050000</td>
#       <td id="T_86de0_row4_col3" class="data row4 col3" >-0.030000</td>
#       <td id="T_86de0_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# CSV correlacao

# %%
matriz.to_csv('data/matriz_correlacao.csv', sep=';', encoding='utf-8-sig', decimal=',')

# %% [markdown]
# ## extra analysis

# %%
ambientais
# Out:
#       Código da Emenda  Ano da Emenda  \
# 69799     202327760019           2023
# 69899     202330420002           2023
# 69942     202310740007           2023
# 69959     202320830015           2023
# 70021     202339150004           2023
# ...                ...            ...
# 93683     202640700020           2026
# 93693     202644830017           2026
# 93805     202640880009           2026
# 93873     202637770008           2026
# 93894     202638050005           2026
#
#                                           Tipo de Emenda  \
# 69799  Emenda Individual - Transferências com Finalid...
# 69899  Emenda Individual - Transferências com Finalid...
# 69942  Emenda Individual - Transferências com Finalid...
# 69959  Emenda Individual - Transferências com Finalid...
# 70021  Emenda Individual - Transferências com Finalid...
# ...                                                  ...
# 93683  Emenda Individual - Transferências com Finalid...
# 93693  Emenda Individual - Transferências com Finalid...
# 93805  Emenda Individual - Transferências com Finalid...
# 93873  Emenda Individual - Transferências com Finalid...
# 93894  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda  Nome do Autor da Emenda Número da emenda  \
# 69799                      2776         ALESSANDRO MOLON               19
# 69899                      3042           ALTINEU CORTES                2
# 69942                      1074           ANDRE DE PAULA                7
# 69959                      2083         ANDRE FIGUEIREDO               15
# 70021                      3915           AROLDO MARTINS                4
# ...                         ...                      ...              ...
# 93683                      4070          TALIRIA PETRONE               20
# 93693                      4483           TARCISIO MOTTA               17
# 93805                      4088  VENEZIANO VITAL DO REGO                9
# 93873                      3777              VITOR LIPPI                8
# 93894                      3805      WELLINGTON FAGUNDES                5
#
#       Localidade de aplicação do recurso Código Município IBGE  \
# 69799                RIO DE JANEIRO (UF)        Sem informação
# 69899                   SÃO GONÇALO - RJ               3304904
# 69942                    ITAPISSUMA - PE               2607752
# 69959                        RUSSAS - CE               2311801
# 70021                        PARANÁ (UF)        Sem informação
# ...                                  ...                   ...
# 93683                RIO DE JANEIRO (UF)        Sem informação
# 93693                RIO DE JANEIRO - RJ               3304557
# 93805                CAMPINA GRANDE - PB               2504009
# 93873                     SÃO PAULO (UF)        Sem informação
# 93894                        CUIABÁ - MT               5103403
#
#             Município  Código UF IBGE  ... Código Ação  \
# 69799  Sem informação         3300000  ...        20WM
# 69899     SÃO GONÇALO         3300000  ...        00SY
# 69942      ITAPISSUMA         2600000  ...        00T5
# 69959          RUSSAS         2300000  ...        2E87
# 70021  Sem informação         4100000  ...        2E87
# ...               ...             ...  ...         ...
# 93683  Sem informação         3300000  ...        21A9
# 93693  RIO DE JANEIRO         3300000  ...        00VD
# 93805  CAMPINA GRANDE         2500000  ...        00TB
# 93873  Sem informação         3500000  ...        2E87
# 93894          CUIABÁ         5100000  ...        8172
#
#                                                Nome Ação  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...
# 69959  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# 70021  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# ...                                                  ...
# 93683  IMPLEMENTACAO DE PROGRAMAS, PLANOS E ACOES PAR...
# 93693  APOIO AO DESENVOLVIMENTO E IMPLEMENTACAO DE AC...
# 93805  APOIO A IMPLANTACAO, AMPLIACAO OU MELHORIAS DE...
# 93873  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# 93894  COORDENACAO E FORTALECIMENTO DO SISTEMA NACION...
#
#       Código Plano Orçamentário  \
# 69799                      0000
# 69899                      0000
# 69942                      0000
# 69959                      0000
# 70021                      0000
# ...                         ...
# 93683                      0000
# 93693                      0000
# 93805                      0000
# 93873                      0000
# 93894                      0000
#
#                                  Nome Plano Orçamentário Valor Empenhado  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...       488667.88
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...     12219069.00
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...       500000.00
# 69959  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       250000.00
# 70021  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       162920.00
# ...                                                  ...             ...
# 93683  IMPLEMENTACAO DE PROGRAMAS, PLANOS E ACOES PAR...       300000.00
# 93693  APOIO AO DESENVOLVIMENTO E IMPLEMENTACAO DE AC...       600000.00
# 93805  APOIO A IMPLANTACAO, AMPLIACAO OU MELHORIAS DE...       500000.00
# 93873  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...      2865000.00
# 93894  COORDENACAO E FORTALECIMENTO DO SISTEMA NACION...      2000000.00
#
#       Valor Liquidado Valor Pago Valor Restos A Pagar Inscritos  \
# 69799            0,00       0,00                       12805,02
# 69899       518333,00  518333,00                    11700736,00
# 69942            0,00       0,00                      143976,05
# 69959            0,00       0,00                       70400,00
# 70021            0,00       0,00                           0,00
# ...               ...        ...                            ...
# 93683       300000,00  300000,00                           0,00
# 93693            0,00       0,00                           0,00
# 93805            0,00       0,00                           0,00
# 93873            0,00       0,00                           0,00
# 93894            0,00       0,00                           0,00
#
#       Valor Restos A Pagar Cancelados Valor Restos A Pagar Pagos
# 69799                            0,00                  475862,86
# 69899                            0,00                       0,00
# 69942                            0,00                  356023,95
# 69959                            0,00                  179600,00
# 70021                            0,00                  162920,00
# ...                               ...                        ...
# 93683                            0,00                       0,00
# 93693                            0,00                       0,00
# 93805                            0,00                       0,00
# 93873                            0,00                       0,00
# 93894                            0,00                       0,00
#
# [269 rows x 28 columns]

# %%
#authors
ambientais.groupby('Nome do Autor da Emenda')['Valor Empenhado'].sum().sort_values(ascending=False).head(30)
# Out:
# Nome do Autor da Emenda
# BANCADA DE TOCANTINS                               71762750.00
# BANCADA DE SANTA CATARINA                          48358320.00
# BRUNO GANEM                                        39461990.69
# MARCELO QUEIROZ                                    38922799.44
# BANCADA DO MATO GROSSO DO SUL                      30000000.00
# BANCADA DE SERGIPE                                 27680777.00
# BANCADA DO RIO GRANDE DO NORTE                     24492366.00
# DELEGADO MATHEUS LAIOLA                            23567695.12
# DELEGADO BRUNO LIMA                                22154713.86
# BANCADA DE PERNAMBUCO                              19600000.00
# BANCADA DO MATO GROSSO                             14000000.00
# ALTINEU CORTES                                     12419069.00
# BANCADA DO AMAPA                                   10000000.00
# COM. MISTA PERMANENTE SOBRE MUDANCAS CLIMATICAS     8975173.00
# DR. FERNANDO MAXIMO                                 8862596.66
# FRED COSTA                                          7499984.20
# KIKO CELEGUIM                                       6241800.00
# LUIZIANNE LINS                                      5597993.00
# TALIRIA PETRONE                                     5229208.00
# VENEZIANO VITAL DO REGO                             5000000.00
# GLAUBER BRAGA                                       4761746.18
# BANCADA DA BAHIA                                    4700000.00
# CELIA XAKRIABA                                      4396090.00
# FERNANDA MELCHIONNA                                 4048507.02
# ERIKA HILTON                                        3985999.67
# VITOR LIPPI                                         3864996.00
# BANCADA DO PIAUI                                    3820000.00
# ANA PAULA LIMA                                      3605000.00
# CELIO STUDART                                       3532854.46
# TABATA AMARAL                                       3220794.00
# Name: Valor Empenhado, dtype: float64

# %%
ambientais
# Out:
#       Código da Emenda  Ano da Emenda  \
# 69799     202327760019           2023
# 69899     202330420002           2023
# 69942     202310740007           2023
# 69959     202320830015           2023
# 70021     202339150004           2023
# ...                ...            ...
# 93683     202640700020           2026
# 93693     202644830017           2026
# 93805     202640880009           2026
# 93873     202637770008           2026
# 93894     202638050005           2026
#
#                                           Tipo de Emenda  \
# 69799  Emenda Individual - Transferências com Finalid...
# 69899  Emenda Individual - Transferências com Finalid...
# 69942  Emenda Individual - Transferências com Finalid...
# 69959  Emenda Individual - Transferências com Finalid...
# 70021  Emenda Individual - Transferências com Finalid...
# ...                                                  ...
# 93683  Emenda Individual - Transferências com Finalid...
# 93693  Emenda Individual - Transferências com Finalid...
# 93805  Emenda Individual - Transferências com Finalid...
# 93873  Emenda Individual - Transferências com Finalid...
# 93894  Emenda Individual - Transferências com Finalid...
#
#       Código do Autor da Emenda  Nome do Autor da Emenda Número da emenda  \
# 69799                      2776         ALESSANDRO MOLON               19
# 69899                      3042           ALTINEU CORTES                2
# 69942                      1074           ANDRE DE PAULA                7
# 69959                      2083         ANDRE FIGUEIREDO               15
# 70021                      3915           AROLDO MARTINS                4
# ...                         ...                      ...              ...
# 93683                      4070          TALIRIA PETRONE               20
# 93693                      4483           TARCISIO MOTTA               17
# 93805                      4088  VENEZIANO VITAL DO REGO                9
# 93873                      3777              VITOR LIPPI                8
# 93894                      3805      WELLINGTON FAGUNDES                5
#
#       Localidade de aplicação do recurso Código Município IBGE  \
# 69799                RIO DE JANEIRO (UF)        Sem informação
# 69899                   SÃO GONÇALO - RJ               3304904
# 69942                    ITAPISSUMA - PE               2607752
# 69959                        RUSSAS - CE               2311801
# 70021                        PARANÁ (UF)        Sem informação
# ...                                  ...                   ...
# 93683                RIO DE JANEIRO (UF)        Sem informação
# 93693                RIO DE JANEIRO - RJ               3304557
# 93805                CAMPINA GRANDE - PB               2504009
# 93873                     SÃO PAULO (UF)        Sem informação
# 93894                        CUIABÁ - MT               5103403
#
#             Município  Código UF IBGE  ... Código Ação  \
# 69799  Sem informação         3300000  ...        20WM
# 69899     SÃO GONÇALO         3300000  ...        00SY
# 69942      ITAPISSUMA         2600000  ...        00T5
# 69959          RUSSAS         2300000  ...        2E87
# 70021  Sem informação         4100000  ...        2E87
# ...               ...             ...  ...         ...
# 93683  Sem informação         3300000  ...        21A9
# 93693  RIO DE JANEIRO         3300000  ...        00VD
# 93805  CAMPINA GRANDE         2500000  ...        00TB
# 93873  Sem informação         3500000  ...        2E87
# 93894          CUIABÁ         5100000  ...        8172
#
#                                                Nome Ação  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...
# 69959  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# 70021  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# ...                                                  ...
# 93683  IMPLEMENTACAO DE PROGRAMAS, PLANOS E ACOES PAR...
# 93693  APOIO AO DESENVOLVIMENTO E IMPLEMENTACAO DE AC...
# 93805  APOIO A IMPLANTACAO, AMPLIACAO OU MELHORIAS DE...
# 93873  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...
# 93894  COORDENACAO E FORTALECIMENTO DO SISTEMA NACION...
#
#       Código Plano Orçamentário  \
# 69799                      0000
# 69899                      0000
# 69942                      0000
# 69959                      0000
# 70021                      0000
# ...                         ...
# 93683                      0000
# 93693                      0000
# 93805                      0000
# 93873                      0000
# 93894                      0000
#
#                                  Nome Plano Orçamentário Valor Empenhado  \
# 69799  APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UN...       488667.88
# 69899  APOIO A PROJETOS E OBRAS DE REABILITACAO, DE A...     12219069.00
# 69942  APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRA...       500000.00
# 69959  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       250000.00
# 70021  APOIO A FORMULACAO E IMPLEMENTACAO DE POLITICA...       162920.00
# ...                                                  ...             ...
# 93683  IMPLEMENTACAO DE PROGRAMAS, PLANOS E ACOES PAR...       300000.00
# 93693  APOIO AO DESENVOLVIMENTO E IMPLEMENTACAO DE AC...       600000.00
# 93805  APOIO A IMPLANTACAO, AMPLIACAO OU MELHORIAS DE...       500000.00
# 93873  IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, ...      2865000.00
# 93894  COORDENACAO E FORTALECIMENTO DO SISTEMA NACION...      2000000.00
#
#       Valor Liquidado Valor Pago Valor Restos A Pagar Inscritos  \
# 69799            0,00       0,00                       12805,02
# 69899       518333,00  518333,00                    11700736,00
# 69942            0,00       0,00                      143976,05
# 69959            0,00       0,00                       70400,00
# 70021            0,00       0,00                           0,00
# ...               ...        ...                            ...
# 93683       300000,00  300000,00                           0,00
# 93693            0,00       0,00                           0,00
# 93805            0,00       0,00                           0,00
# 93873            0,00       0,00                           0,00
# 93894            0,00       0,00                           0,00
#
#       Valor Restos A Pagar Cancelados Valor Restos A Pagar Pagos
# 69799                            0,00                  475862,86
# 69899                            0,00                       0,00
# 69942                            0,00                  356023,95
# 69959                            0,00                  179600,00
# 70021                            0,00                  162920,00
# ...                               ...                        ...
# 93683                            0,00                       0,00
# 93693                            0,00                       0,00
# 93805                            0,00                       0,00
# 93873                            0,00                       0,00
# 93894                            0,00                       0,00
#
# [269 rows x 28 columns]

# %%
ambientais.groupby(['Nome do Autor da Emenda', 'Localidade de aplicação do recurso'])['Valor Empenhado'].sum().sort_values(ascending=False).head(25)
# Out:
# Nome do Autor da Emenda                          Localidade de aplicação do recurso
# BANCADA DE TOCANTINS                             MÚLTIPLO                              71762750.00
# BANCADA DE SANTA CATARINA                        MÚLTIPLO                              48358320.00
# BRUNO GANEM                                      SÃO PAULO (UF)                        39461990.69
# MARCELO QUEIROZ                                  Nacional                              38922799.44
# BANCADA DO MATO GROSSO DO SUL                    MÚLTIPLO                              30000000.00
# BANCADA DE SERGIPE                               MÚLTIPLO                              27680777.00
# DELEGADO MATHEUS LAIOLA                          PARANÁ (UF)                           23567695.12
# DELEGADO BRUNO LIMA                              SÃO PAULO (UF)                        22154713.86
# BANCADA DO RIO GRANDE DO NORTE                   RIO GRANDE DO NORTE (UF)              18992366.00
# BANCADA DE PERNAMBUCO                            PERNAMBUCO (UF)                       14600000.00
# BANCADA DO MATO GROSSO                           VÁRZEA GRANDE - MT                    14000000.00
# ALTINEU CORTES                                   SÃO GONÇALO - RJ                      12219069.00
# BANCADA DO AMAPA                                 AMAPÁ (UF)                            10000000.00
# COM. MISTA PERMANENTE SOBRE MUDANCAS CLIMATICAS  Nacional                               8975173.00
# DR. FERNANDO MAXIMO                              RONDÔNIA (UF)                          5865000.00
# LUIZIANNE LINS                                   CEARÁ (UF)                             5597993.00
# BANCADA DO RIO GRANDE DO NORTE                   NATAL - RN                             5500000.00
# BANCADA DE PERNAMBUCO                            JABOATÃO DOS GUARARAPES - PE           5000000.00
# VENEZIANO VITAL DO REGO                          PARAÍBA (UF)                           4500000.00
# FRED COSTA                                       MÚLTIPLO                               4499984.20
# TALIRIA PETRONE                                  RIO DE JANEIRO (UF)                    4429208.00
# VITOR LIPPI                                      SÃO PAULO (UF)                         3864996.00
# BANCADA DO PIAUI                                 PIAUÍ (UF)                             3820000.00
# BANCADA DA BAHIA                                 BAHIA (UF)                             3700000.00
# CELIO STUDART                                    CEARÁ (UF)                             3532854.46
# Name: Valor Empenhado, dtype: float64

# %%
#main earmarks
ambientais.groupby('Nome Ação')['Valor Empenhado'].agg(['count', 'sum']).sort_values('sum', ascending=False).head(30)
# Out:
#                                                     count           sum
# Nome Ação
# IMPLEMENTACAO DA AGENDA NACIONAL DE PROTECAO, D...     72  1.830121e+08
# APOIO A PROJETOS E OBRAS DE REABILITACAO, DE AC...     19  1.361576e+08
# APOIO A REALIZACAO DE ESTUDOS, PROJETOS E OBRAS...      6  5.801278e+07
# APOIO A SISTEMAS DE DRENAGEM URBANA SUSTENTAVEL...      1  3.000000e+07
# IMPLEMENTACAO DE ACOES DE CIDADANIA E EDUCACAO ...     37  2.294273e+07
# IMPLEMENTACAO DE PROGRAMAS, PLANOS E ACOES PARA...     29  1.996795e+07
# APOIO A CONSTRUCAO DA BARRAGEM OITICICA                 1  1.899237e+07
# APOIO A REGULARIZACAO FUNDIARIA URBANA                  5  1.780000e+07
# APOIO AO DESENVOLVIMENTO E IMPLEMENTACAO DE ACO...     15  1.535596e+07
# APOIO A IMPLANTACAO DA ADUTORA DO AGRESTE               1  1.460000e+07
# APOIO A IMPLANTACAO, AMPLIACAO OU MELHORIAS DE ...      8  1.250200e+07
# FISCALIZACAO AMBIENTAL E PREVENCAO E COMBATE A ...      3  1.034462e+07
# COORDENACAO E FORTALECIMENTO DO SISTEMA NACIONA...      8  8.993546e+06
# APOIO A CRIACAO, GESTAO E IMPLEMENTACAO DAS UNI...     12  3.890216e+06
# IMPLEMENTACAO DE POLITICAS PARA BIODIVERSIDADE,...      7  3.415000e+06
# APOIO A PLANOS, PROJETOS E OBRAS DE REDUCAO DE ...      4  3.400000e+06
# GESTAO TERRITORIAL E SOCIOAMBIENTAL DE PAISAGEN...      4  3.398511e+06
# CONSERVACAO E RECUPERACAO DE BACIAS HIDROGRAFICAS       3  2.650000e+06
# APOIO A IMPLANTACAO, AMPLIACAO, MELHORIAS OU AD...      3  2.648100e+06
# PREVENCAO E CONTROLE DE INCENDIOS FLORESTAIS NA...      5  2.520961e+06
# APOIO AO PLANEJAMENTO E A GESTAO URBANA MUNICIP...      1  1.629209e+06
# ACOES DE PROTECAO E DEFESA CIVIL                        4  1.600000e+06
# IMPLEMENTACAO E MONITORAMENTO DA POLITICA NACIO...      3  1.400000e+06
# CONSTRUCAO DE SISTEMA INTEGRADO DE ABASTECIMENT...      1  1.200000e+06
# GESTAO DO USO SUSTENTAVEL DA BIODIVERSIDADE E R...      3  1.199994e+06
# ENFRENTAMENTO DOS PROCESSOS DE DESERTIFICACAO, ...      3  1.000000e+06
# MONITORAMENTO AMBIENTAL E GESTAO DA INFORMACAO ...      2  9.070000e+05
# APOIO A MELHORIA HABITACIONAL                           1  7.000000e+05
# IMPLEMENTACAO DA POLITICA NACIONAL DE RECURSOS ...      2  6.993485e+05
# FOMENTO A PROJETOS DE DESENVOLVIMENTO SUSTENTAV...      1  5.000000e+05

# %% [markdown]
# ## Environmental money by state and region

# %%
ambientais.groupby('UF')['Valor Empenhado'].agg(['count', 'sum']).sort_values('sum', ascending=False)
# Out:
#                      count          sum
# UF
# SÃO PAULO               51  93258966.51
# TOCANTINS                6  72762750.00
# Sem informação          31  71149463.09
# SANTA CATARINA           9  54084785.00
# RIO DE JANEIRO          36  40472528.09
# MATO GROSSO DO SUL       6  33629000.00
# SERGIPE                  3  28980777.00
# PERNAMBUCO              13  26549452.00
# RIO GRANDE DO NORTE      6  25800694.00
# PARANÁ                   7  25030615.12
# MINAS GERAIS            22  21302054.79
# MATO GROSSO              3  16300000.00
# CEARÁ                   11  11805056.46
# AMAPÁ                    1  10000000.00
# RIO GRANDE DO SUL       15   9845217.68
# GOIÁS                   11   7904743.11
# BAHIA                    8   7788821.26
# RONDÔNIA                 2   5865000.00
# PARAÍBA                  4   5300000.00
# ESPÍRITO SANTO           9   4198141.41
# PIAUÍ                    3   4020000.00
# AMAZONAS                 4   2991040.96
# Múltiplo                 3   2212008.00
# DISTRITO FEDERAL         4   1857616.00
# ALAGOAS                  1    200000.00

# %%
ambientais.groupby('Região')['Valor Empenhado'].agg(['count', 'sum']).sort_values('sum', ascending=False)
# Out:
#               count           sum
# Região
# Sudeste         118  1.592317e+08
# Nordeste         49  1.104448e+08
# Norte            13  9.161879e+07
# Sul              31  8.896062e+07
# Nacional         31  7.114946e+07
# Centro-Oeste     24  5.969136e+07
# Múltiplo          3  2.212008e+06

# %%
#year to year
ambientais.groupby('Ano da Emenda')['Valor Empenhado'].agg(['count', 'sum'])
# Out:
#                count           sum
# Ano da Emenda
# 2023              44  1.098463e+08
# 2024              88  1.762183e+08
# 2025              89  2.091665e+08
# 2026              48  8.807772e+07

# %% [markdown]
# ## Events vs money by state

# %%
recentes
# Out:
#                     Protocolo_S2iD       Nome_Municipio Sigla_UF    regiao  \
# 62115  BA-F-2907806-13214-20230101        Cícero Dantas       BA  Nordeste
# 62116  MG-F-3153400-13214-20230101  Presidente Olegário       MG   Sudeste
# 62117  MG-F-3130903-13214-20230101              Inhapim       MG   Sudeste
# 62118  MG-F-3128402-13214-20230101              Guarani       MG   Sudeste
# 62119  MG-F-3155801-13214-20230101            Rio Pomba       MG   Sudeste
# ...                            ...                  ...      ...       ...
# 76186  SC-F-4212106-13214-20251231             Palmitos       SC       Sul
# 76187  MG-F-3147907-13214-20251231               Passos       MG   Sudeste
# 76188  SC-F-4212304-13214-20251231          Paulo Lopes       SC       Sul
# 76189  SC-F-4216305-13214-20251231     São João Batista       SC       Sul
# 76190  SC-F-4219606-13214-20251231            Xavantina       SC       Sul
#
#             Data_Registro Data_Evento  Cod_Cobrade  tipologia  \
# 62115 2023-01-03 15:14:21  2023-01-01        13214         13
# 62116 2023-01-18 17:06:06  2023-01-01        13214         13
# 62117 2023-01-19 11:02:49  2023-01-01        13214         13
# 62118 2023-01-05 11:25:07  2023-01-01        13214         13
# 62119 2023-01-05 13:28:49  2023-01-01        13214         13
# ...                   ...         ...          ...        ...
# 76186 2026-01-02 00:00:00  2025-12-31        13214         13
# 76187 2026-01-06 00:00:00  2025-12-31        13214         13
# 76188 2026-01-07 00:00:00  2025-12-31        13214         13
# 76189 2026-01-01 00:00:00  2025-12-31        13214         13
# 76190 2026-01-19 00:00:00  2025-12-31        13214         13
#
#       descricao_tipologia grupo_de_desastre  ...  PEPL_total_publico  \
# 62115     Chuvas Intensas       Hidrológico  ...             52000.0
# 62116     Chuvas Intensas       Hidrológico  ...            150000.0
# 62117     Chuvas Intensas       Hidrológico  ...            700000.0
# 62118     Chuvas Intensas       Hidrológico  ...                 0.0
# 62119     Chuvas Intensas       Hidrológico  ...              2000.0
# ...                   ...               ...  ...                 ...
# 76186     Chuvas Intensas       Hidrológico  ...             90000.0
# 76187     Chuvas Intensas       Hidrológico  ...            620000.0
# 76188     Chuvas Intensas       Hidrológico  ...                 0.0
# 76189     Chuvas Intensas       Hidrológico  ...            350000.0
# 76190     Chuvas Intensas       Hidrológico  ...           2500000.0
#
#                                           PEPR_Descricao  \
# 62115  ATÉ O MOMENTO NÃO AVALIADO DEVIDO A PRECARIEDA...
# 62116  PREJUÍZOS NA AGRICULTURA SENDO ESTA A FRUTICUL...
# 62117  COM QUEDAS DE ESTRAS E PONTES IMPOSSIBILITOU Q...
# 62118  Devido às chuvas intensas ocorridas no municíp...
# 62119  Devido às chuvas intensas ocorridas no municíp...
# ...                                                  ...
# 76186  As chuvas intensas e o elevado escoamento supe...
# 76187  As intensas chuvas inviabilizaram as estradas ...
# 76188                                                NaN
# 76189  Com efeito do desastre ocasionou a interrupção...
# 76190                      Não houve prejuizos privados.
#
#       PEPR_Agricultura (R$) PEPR_Pecuária (R$)  PEPR_Indústria (R$)  \
# 62115                   0.0                0.0                  0.0
# 62116              100000.0          2000000.0                  0.0
# 62117              600000.0           450000.0                  0.0
# 62118                   0.0                0.0                  0.0
# 62119                   0.0                0.0                  0.0
# ...                     ...                ...                  ...
# 76186              100000.0            80000.0                  0.0
# 76187               10000.0            10000.0                  0.0
# 76188                   0.0                0.0                  0.0
# 76189              100000.0                0.0                  0.0
# 76190                   0.0                0.0                  0.0
#
#        PEPR_Comércio (R$)  PEPR_Serviços (R$)  PEPR_total_privado   PE_PLePR  \
# 62115                 0.0                 0.0                 0.0    52000.0
# 62116                 0.0                 0.0           2100000.0  2250000.0
# 62117                 0.0                 0.0           1050000.0  1750000.0
# 62118                 0.0                 0.0                 0.0        0.0
# 62119                 0.0                 0.0                 0.0     2000.0
# ...                   ...                 ...                 ...        ...
# 76186                 0.0             90000.0            270000.0   360000.0
# 76187                 0.0                 0.0             20000.0   640000.0
# 76188                 0.0                 0.0                 0.0        0.0
# 76189                 0.0                 0.0            100000.0   450000.0
# 76190                 0.0                 0.0                 0.0  2500000.0
#
#        Ano_Evento
# 62115        2023
# 62116        2023
# 62117        2023
# 62118        2023
# 62119        2023
# ...           ...
# 76186        2025
# 76187        2025
# 76188        2025
# 76189        2025
# 76190        2025
#
# [5779 rows x 71 columns]

# %%
#mapping states to initials
ufs = {'ACRE': 'AC', 'ALAGOAS': 'AL', 'AMAPÁ': 'AP', 'AMAZONAS': 'AM', 'BAHIA': 'BA', 'CEARÁ': 'CE', 'DISTRITO FEDERAL': 'DF', 'ESPÍRITO SANTO': 'ES', 'GOIÁS': 'GO', 'MARANHÃO': 'MA', 'MATO GROSSO': 'MT', 'MATO GROSSO DO SUL': 'MS', 'MINAS GERAIS': 'MG', 'PARÁ': 'PA', 'PARAÍBA': 'PB', 'PARANÁ': 'PR', 'PERNAMBUCO': 'PE', 'PIAUÍ': 'PI', 'RIO DE JANEIRO': 'RJ', 'RIO GRANDE DO NORTE': 'RN', 'RIO GRANDE DO SUL': 'RS', 'RONDÔNIA': 'RO', 'RORAIMA': 'RR', 'SANTA CATARINA': 'SC', 'SÃO PAULO': 'SP', 'SERGIPE': 'SE', 'TOCANTINS': 'TO'}

# %%
ambientais['Sigla_UF'] = ambientais['UF'].map(ufs)
estados = pd.concat([
    recentes.groupby('Sigla_UF').size().rename('Eventos'),
    ambientais.groupby('Sigla_UF')['Valor Empenhado'].sum().rename('Valor Empenhado')
], axis=1).fillna(0)

estados['% Eventos'] = (estados['Eventos']/estados['Eventos'].sum() * 100).round(1)
estados['% Dinheiro'] = (estados['Valor Empenhado']/estados['Valor Empenhado'].sum() * 100).round(1)

estados.sort_values('% Eventos', ascending=False)
# Out:
#           Eventos  Valor Empenhado  % Eventos  % Dinheiro
# Sigla_UF
# RS           1434       9845217.68       24.8         1.9
# SC           1183      54084785.00       20.5        10.6
# MG            851      21302054.79       14.7         4.2
# PA            336             0.00        5.8         0.0
# RJ            190      40472528.09        3.3         7.9
# SP            185      93258966.51        3.2        18.3
# MA            178             0.00        3.1         0.0
# PR            174      25030615.12        3.0         4.9
# MS            172      33629000.00        3.0         6.6
# PE            172      26549452.00        3.0         5.2
# BA            162       7788821.26        2.8         1.5
# ES            134       4198141.41        2.3         0.8
# RN             98      25800694.00        1.7         5.1
# CE             92      11805056.46        1.6         2.3
# AM             72       2991040.96        1.2         0.6
# MT             67      16300000.00        1.2         3.2
# AC             56             0.00        1.0         0.0
# GO             56       7904743.11        1.0         1.6
# AL             46        200000.00        0.8         0.0
# PI             33       4020000.00        0.6         0.8
# SE             32      28980777.00        0.6         5.7
# RO             23       5865000.00        0.4         1.2
# AP             13      10000000.00        0.2         2.0
# PB              8       5300000.00        0.1         1.0
# RR              4             0.00        0.1         0.0
# TO              7      72762750.00        0.1        14.3
# DF              1       1857616.00        0.0         0.4

# %%
CSV ESTADOS EVENTOS DINHEIRO

# %%
estados.to_csv('data/estados_eventos_dinheiro.csv', index=False, sep=';', encoding='utf-8-sig', decimal=',')

# %%
#Slope file for Flourish
estados = estados.reset_index()
slope = estados[['Sigla_UF']].copy()
slope['Share of events'] = estados['Eventos'] / estados['Eventos'].sum()*100
slope['Share of money'] = estados['Valor Empenhado'] / estados['Valor Empenhado'].sum() * 100

slope.to_csv('data/slope_estados.csv', index=False)

slope.head()
# Out:
#   Sigla_UF  Share of events  Share of money
# 0       AC         0.969026        0.000000
# 1       AL         0.795985        0.039220
# 2       AM         1.245890        0.586539
# 3       AP         0.224952        1.960987
# 4       BA         2.803253        1.527378

# %% [markdown]
# ## Maps
# Municipality boundaries from AdaptaBrasil API

# %%
url= "https://sistema.adaptabrasil.mcti.gov.br/api/geometria/data/60001/BR/null/2015/municipio/GEOJSONz/adaptabrasil"
location = requests.get(url).json()['location']
zip_bytes = requests.get(location).content
open('data/dados_brutos/municipios.zip', 'wb').write(zip_bytes)
# Out:
# 2654141

# %%
import geopandas as gpd

municipios = gpd.read_file('zip://data/dados_brutos/municipios.zip')

municipios.head
# Out:
# <bound method NDFrame.head of         id                           name geocod_ibge  value  \
# 0        1                       Caiuá/SP     3509106   0.40
# 1        2                    Castilho/SP     3511003   0.46
# 2        3                     Dracena/SP     3514403   0.34
# 3        4            Estrela do Norte/SP     3515301   0.37
# 4        5  Euclides da Cunha Paulista/SP     3515350   0.39
# ...    ...                            ...         ...    ...
# 5565  5568               Teixeirópolis/RO     1101559   0.38
# 5566  5569                   Theobroma/RO     1101609   0.28
# 5567  5570                       Urupá/RO     1101708   0.39
# 5568  5571               Vale do Anari/RO     1101757   0.33
# 5569  5572             Vale do Paraíso/RO     1101807   0.35
#
#                                                   style  \
# 0     {'color': '#d7d7d7', 'fillcolor': '#FFCD00', '...
# 1     {'color': '#d7d7d7', 'fillcolor': '#FFCD00', '...
# 2     {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 3     {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 4     {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# ...                                                 ...
# 5565  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 5566  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 5567  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 5568  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 5569  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
#
#                                                geometry
# 0     MULTIPOLYGON (((-51.86 -21.5807, -51.8581 -21....
# 1     MULTIPOLYGON (((-51.42 -20.68, -51.42 -20.69, ...
# 2     MULTIPOLYGON (((-51.49 -21.43, -51.48 -21.43, ...
# 3     MULTIPOLYGON (((-51.57 -22.4, -51.57 -22.49, -...
# 4     MULTIPOLYGON (((-52.45 -22.61, -52.46 -22.61, ...
# ...                                                 ...
# 5565  MULTIPOLYGON (((-62.12 -10.9, -62.16 -11, -62....
# 5566  MULTIPOLYGON (((-61.95 -9.95, -61.96 -9.95, -6...
# 5567  MULTIPOLYGON (((-62.16 -11.03, -62.16 -11.03, ...
# 5568  MULTIPOLYGON (((-61.57 -9.72, -61.59 -9.71, -6...
# 5569  MULTIPOLYGON (((-61.97 -10.07, -61.97 -10.07, ...
#
# [5570 rows x 6 columns]>

# %%
municipios.head()
# Out:
#    id                           name geocod_ibge  value  \
# 0   1                       Caiuá/SP     3509106   0.40
# 1   2                    Castilho/SP     3511003   0.46
# 2   3                     Dracena/SP     3514403   0.34
# 3   4            Estrela do Norte/SP     3515301   0.37
# 4   5  Euclides da Cunha Paulista/SP     3515350   0.39
#
#                                                style  \
# 0  {'color': '#d7d7d7', 'fillcolor': '#FFCD00', '...
# 1  {'color': '#d7d7d7', 'fillcolor': '#FFCD00', '...
# 2  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 3  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
# 4  {'color': '#d7d7d7', 'fillcolor': '#A9DE00', '...
#
#                                             geometry
# 0  MULTIPOLYGON (((-51.86 -21.5807, -51.8581 -21....
# 1  MULTIPOLYGON (((-51.42 -20.68, -51.42 -20.69, ...
# 2  MULTIPOLYGON (((-51.49 -21.43, -51.48 -21.43, ...
# 3  MULTIPOLYGON (((-51.57 -22.4, -51.57 -22.49, -...
# 4  MULTIPOLYGON (((-52.45 -22.61, -52.46 -22.61, ...

# %%
municipios['geometry'] = municipios.geometry.simplify(0.01)
municipios = municipios[['geocod_ibge', 'geometry']]

# %%
mapa = municipios.merge(df_final, left_on='geocod_ibge', right_on='Código IBGE')
mapa.head(10)
# Out:
#   geocod_ibge                                           geometry Código IBGE  \
# 0     3509106  POLYGON ((-51.86 -21.5807, -51.8429 -21.6131, ...     3509106
# 1     3511003  POLYGON ((-51.42 -20.68, -51.45 -20.77, -51.45...     3511003
# 2     3514403  POLYGON ((-51.49 -21.43, -51.48 -21.53, -51.51...     3514403
# 3     3515301  POLYGON ((-51.57 -22.4, -51.57 -22.49, -51.6 -...     3515301
# 4     3515350  POLYGON ((-52.44 -22.61, -52.51 -22.63, -52.54...     3515350
# 5     3528700  POLYGON ((-51.92 -22.01, -51.89 -22.01, -51.87...     3528700
# 6     3530201  POLYGON ((-51.74 -22.18, -51.74 -22.2, -51.77 ...     3530201
# 7     3531605  POLYGON ((-51.5 -21.22, -51.49 -21.25, -51.51 ...     3531605
# 8     3532207  POLYGON ((-51.49 -22.36, -51.52 -22.46, -51.47...     3532207
# 9     3533106  POLYGON ((-51.63 -21.32, -51.62 -21.36, -51.67...     3533106
#
#                        Município  Índice Deslizamento Cor Deslizamento  \
# 0                       Caiuá/SP                 0.40          #FFCD00
# 1                    Castilho/SP                 0.46          #FFCD00
# 2                     Dracena/SP                 0.34          #A9DE00
# 3            Estrela do Norte/SP                 0.37          #A9DE00
# 4  Euclides da Cunha Paulista/SP                 0.39          #A9DE00
# 5             Marabá Paulista/SP                 0.46          #FFCD00
# 6     Mirante do Paranapanema/SP                 0.50          #FFCD00
# 7               Monte Castelo/SP                 0.35          #A9DE00
# 8                   Narandiba/SP                 0.22          #A9DE00
# 9           Nova Guataporanga/SP                 0.44          #FFCD00
#
#   Label Deslizamento  Índice Inundação Cor Inundação Label Inundação  \
# 0              Médio              0.56       #FFCD00           Médio
# 1              Médio              0.58       #FFCD00           Médio
# 2              Baixo              0.49       #FFCD00           Médio
# 3              Baixo              0.45       #FFCD00           Médio
# 4              Baixo              0.48       #FFCD00           Médio
# 5              Médio              0.56       #FFCD00           Médio
# 6              Médio              0.70       #FF8300            Alto
# 7              Baixo              0.44       #FFCD00           Médio
# 8              Baixo              0.22       #A9DE00           Baixo
# 9              Médio              0.50       #FFCD00           Médio
#
#    Valor Empenhado  Índice Risco Médio Label Risco Médio
# 0              NaN               0.480            Medium
# 1              NaN               0.520            Medium
# 2              NaN               0.415            Medium
# 3              NaN               0.410            Medium
# 4              NaN               0.435            Medium
# 5              NaN               0.510            Medium
# 6              NaN               0.600              High
# 7              NaN               0.395            Medium
# 8              NaN               0.220               Low
# 9              NaN               0.470            Medium

# %% [markdown]
# Map files for Flourish (ive had a lot of help here)

# %%
colunas = ['geocod_ibge', 'Município', 'Índice Risco Médio', 'Label Risco Médio', 'geometry']
mapa[colunas].to_file('data/mapa_risco.geojson', driver='GeoJSON')

# %%
mapa_alto = mapa[mapa['Label Risco Médio'].isin(['High', 'Very high'])].copy()

mapa_alto['recebeu_ambiental']= mapa_alto['Valor Empenhado'].notna()
mapa_alto['risco_verba'] =(mapa_alto['Índice Risco Médio']== 1.0) &(mapa_alto['Valor Empenhado'].isna())
mapa_alto['Emenda'] = mapa_alto['recebeu_ambiental'].map({True:'Received environmental earmark', False: 'No environmental earmark'})
colunas_alto = colunas +['Valor Empenhado', 'recebeu_ambiental', 'risco_verba', 'Emenda']
mapa_alto[colunas_alto].to_file('data/mapa_risco_alto.geojson', driver='GeoJSON')
len(mapa), len(mapa_alto), mapa_alto['recebeu_ambiental'].sum(), mapa_alto['risco_verba'].sum()
# Out:
# (5570, 1299, np.int64(14), np.int64(4))

# %% [markdown]
# ## Center points for the marker layers

# %%
mapa_alto
# Out:
#      geocod_ibge                                           geometry  \
# 6        3530201  POLYGON ((-51.74 -22.18, -51.74 -22.2, -51.77 ...
# 11       3535408  POLYGON ((-51.83 -21.37, -51.77 -21.39, -51.75...
# 13       3538303  POLYGON ((-51.61 -21.68, -51.62 -21.72, -51.59...
# 14       3541208  POLYGON ((-51.42 -21.87, -51.42 -21.92, -51.43...
# 21       3547700  POLYGON ((-51.59 -21.9, -51.55 -21.91, -51.55 ...
# ...          ...                                                ...
# 5513     1304203  POLYGON ((-64.07 -3.7, -64.08 -3.77, -64.1 -3....
# 5516     1304302  POLYGON ((-60.04 0.26, -59.19 0.26, -59.19 0.2...
# 5517     1304401  POLYGON ((-57.29 -2.49, -57.45 -2.6, -57.43 -2...
# 5532     1100155  POLYGON ((-62.12 -10.9, -62.31 -10.83, -62.35 ...
# 5533     1100189  POLYGON ((-60.46 -11.46, -60.47 -11.49, -60.44...
#
#      Código IBGE                   Município  Índice Deslizamento  \
# 6        3530201  Mirante do Paranapanema/SP                 0.50
# 11       3535408                 Panorama/SP                 0.62
# 13       3538303                Piquerobi/SP                 0.58
# 14       3541208     Presidente Bernardes/SP                 0.56
# 21       3547700          Santo Anastácio/SP                 0.52
# ...          ...                         ...                  ...
# 5513     1304203                     Tefé/AM                 0.79
# 5516     1304302                  Urucará/AM                 0.81
# 5517     1304401              Urucurituba/AM                 0.89
# 5532     1100155      Ouro Preto do Oeste/RO                 0.56
# 5533     1100189            Pimenta Bueno/RO                 0.52
#
#      Cor Deslizamento Label Deslizamento  Índice Inundação Cor Inundação  \
# 6             #FFCD00              Médio              0.70       #FF8300
# 11            #FF8300               Alto              0.58       #FFCD00
# 13            #FFCD00              Médio              0.75       #FF8300
# 14            #FFCD00              Médio              0.76       #FF8300
# 21            #FFCD00              Médio              0.69       #FF8300
# ...               ...                ...               ...           ...
# 5513          #FF8300               Alto              0.85       #F40000
# 5516          #F40000         Muito alto              0.73       #FF8300
# 5517          #F40000         Muito alto              0.84       #F40000
# 5532          #FFCD00              Médio              0.71       #FF8300
# 5533          #FFCD00              Médio              0.73       #FF8300
#
#      Label Inundação  Valor Empenhado  Índice Risco Médio Label Risco Médio  \
# 6               Alto              NaN               0.600              High
# 11             Médio              NaN               0.600              High
# 13              Alto              NaN               0.665              High
# 14              Alto              NaN               0.660              High
# 21              Alto              NaN               0.605              High
# ...              ...              ...                 ...               ...
# 5513      Muito alto              NaN               0.820         Very high
# 5516            Alto              NaN               0.770              High
# 5517      Muito alto              NaN               0.865         Very high
# 5532            Alto              NaN               0.635              High
# 5533            Alto              NaN               0.625              High
#
#       recebeu_ambiental  risco_verba                    Emenda
# 6                 False        False  No environmental earmark
# 11                False        False  No environmental earmark
# 13                False        False  No environmental earmark
# 14                False        False  No environmental earmark
# 21                False        False  No environmental earmark
# ...                 ...          ...                       ...
# 5513              False        False  No environmental earmark
# 5516              False        False  No environmental earmark
# 5517              False        False  No environmental earmark
# 5532              False        False  No environmental earmark
# 5533              False        False  No environmental earmark
#
# [1299 rows x 16 columns]

# %%
pontos = mapa_alto[mapa_alto['recebeu_ambiental']].copy()
pontos['latitude'] = pontos.geometry.representative_point().y
pontos['longitude'] = pontos.geometry.representative_point().x
pontos = pontos[['Município', 'latitude', 'longitude']].rename(columns={'Município': 'name'})

pontos.to_csv('data/pontos_14.csv', index=False)

pontos
# Out:
#                             name   latitude  longitude
# 1698    Campos dos Goytacazes/RJ -21.640000 -41.325556
# 1736               Petrópolis/RJ -22.400000 -43.181667
# 1749           Rio de Janeiro/RJ -22.943377 -43.470174
# 1754              São Gonçalo/RJ -22.821564 -42.996656
# 1767              Teresópolis/RJ -22.295000 -42.867500
# 1769                Três Rios/RJ -22.125000 -43.108375
# 1837                    Bauru/SP -22.250000 -49.156667
# 2574                   Canoas/RS -29.895000 -51.182500
# 2584                   Esteio/RS -29.850000 -51.182500
# 3898                    Natal/RN  -5.810000 -35.222500
# 4028           Campina Grande/PB  -7.265000 -35.962500
# 4287  Jaboatão dos Guararapes/PE  -8.145000 -35.014167
# 4800                 Salvador/BA -12.880000 -38.483000
# 5338                  Curiúva/PR -23.995000 -50.470000

# %%
pontos4 = mapa_alto[mapa_alto['risco_verba']].copy()

pontos4['latitude'] = pontos4.geometry.representative_point().y
pontos4['longitude'] = pontos4.geometry.representative_point().x

pontos4 = pontos4[['Município', 'latitude', 'longitude']].rename(columns={'Município': 'name'})

pontos4.to_csv('data/pontos_4.csv', index=False)

pontos4
# Out:
#                 name  latitude  longitude
# 4121  Pilõezinhos/PB     -6.86 -35.551000
# 4204   Água Preta/PE     -8.66 -35.478500
# 4283       Itambé/PE     -7.44 -35.125833
# 5026         Afuá/PA     -0.23 -50.740246

# %%
#check para
dfemendas[dfemendas['UF'] == 'PARÁ']['Valor Empenhado'].sum()
# Out:
# np.float64(4623611603.61)

# %%
recentes[recentes['Sigla_UF'] == 'PA'].shape[0]
# Out:
# 336

# %%
recentes[recentes['Sigla_UF'] == 'PA']['descricao_tipologia'].value_counts()
# Out:
# descricao_tipologia
# Chuvas Intensas       254
# Alagamentos            24
# Enxurradas             20
# Movimento de Massa     19
# Inundações             19
# Name: count, dtype: int64
